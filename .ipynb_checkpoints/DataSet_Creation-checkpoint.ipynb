# %%
# Importing the necessary packages
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading in the data set
home =pd.read_csv('csv_files/home_teams.csv', header=0)
away =pd.read_csv('csv_files/away_teams.csv', header=0)

# %%
# Dropping the unnamed column 
home = home.drop(['Unnamed: 0'], axis=1)

# %%
home.columns
# Out:
# Index(['TEAM', 'DATE', 'MATCHUP', 'W/L', 'MIN', 'PTS', 'FGM', 'FGA', 'FGPerc',
#        '3PM', '3PA', 'ThreePPerc', 'FTM', 'FTA', 'FTPerc', 'OREB', 'DREB',
#        'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', '+/', 'EFGPerc', 'FTR',
#        'TOVPerc'],
#       dtype='object')

# %%
# Renaming the columns in to make them all home orientated 
home.rename(columns={'TEAM':'H_TEAM','PTS':'H_PTS','FGM':'H_FGM','FGA':'H_FGA', 'FGPerc':'H_FGPerc', 
                    '3PM':'H_3PM', '3PA':'H_3PA', 'ThreePPerc':'H_ThreePPerc', 'FTM':'H_FTM', 'FTA':'H_FTA', 
                    'FTPerc':'H_FTPerc', 'OREB':'H_OREB', 'DREB':'H_DREB', 'REB':'H_REB', 'AST':'H_AST',
                    'STL':'H_STL', 'BLK':'H_BLK', 'TOV':'H_TOV', 'PF':'H_PF', '+/':'H_+/', 'EFGPerc':'H_EFGPerc',
                    'FTR':'H_FTR', 'TOVPerc':'H_TOVPerc'}, inplace=True)

# %%
away = away.drop(['Unnamed: 0'], axis=1)

# %%
# Renaming the columns in to make them all away orientated 
away.rename(columns={'TEAM':'A_TEAM','W/L':'A_W/L','MIN':'A_MIN','PTS':'A_PTS','FGM':'A_FGM','FGA':'A_FGA', 'FGPerc':'A_FGPerc', 
                    '3PM':'A_3PM', '3PA':'A_3PA', 'ThreePPerc':'A_ThreePPerc', 'FTM':'A_FTM', 'FTA':'A_FTA', 
                    'FTPerc':'A_FTPerc', 'OREB':'A_OREB', 'DREB':'A_DREB', 'REB':'A_REB', 'AST':'A_AST',
                    'STL':'A_STL', 'BLK':'A_BLK', 'TOV':'A_TOV', 'PF':'A_PF', '+/':'A_+/', 'EFGPerc':'A_EFGPerc',
                    'FTR':'A_FTR', 'TOVPerc':'A_TOVPerc'}, inplace=True)

# %%
away.columns
# Out:
# Index(['A_TEAM', 'DATE', 'MATCHUP', 'A_W/L', 'A_MIN', 'A_PTS', 'A_FGM',
#        'A_FGA', 'A_FGPerc', 'A_3PM', 'A_3PA', 'A_ThreePPerc', 'A_FTM', 'A_FTA',
#        'A_FTPerc', 'A_OREB', 'A_DREB', 'A_REB', 'A_AST', 'A_STL', 'A_BLK',
#        'A_TOV', 'A_PF', 'A_+/', 'A_EFGPerc', 'A_FTR', 'A_TOVPerc'],
#       dtype='object')

# %%
home.head(2)
# Out:
#   H_TEAM    DATE      MATCHUP W/L  MIN  H_PTS  H_FGM  H_FGA  H_FGPerc  H_3PM  \
# 0    GSW  6/5/19  GSW vs. TOR   L  241    109     36     91      39.6     12
# 1    TOR  6/2/19  TOR vs. GSW   L  240    104     35     94      37.2     11
#
#      ...      H_REB  H_AST  H_STL  H_BLK  H_TOV  H_PF  H_+/  H_EFGPerc  \
# 0    ...         41     25      8      3     14    21 -14.0   0.461538
# 1    ...         49     17      8      2     15    22  -5.0   0.430851
#
#       H_FTR  H_TOVPerc
# 0  0.329670  11.844332
# 1  0.276596  12.454334
#
# [2 rows x 27 columns]

# %%
# Creating an idential Away Team Variable to join the datasets on 
home['Away_Team'] = home['MATCHUP'].str[-3:]

# %%
# Creating an idential Away Team Variable to join the datasets on 
away['Away_Team'] = away['MATCHUP'].str[:3]

# %%
away.head(2)
# Out:
#   A_TEAM    DATE    MATCHUP A_W/L  A_MIN  A_PTS  A_FGM  A_FGA  A_FGPerc  \
# 0    TOR  6/5/19  TOR @ GSW     W    239    123     43     82      52.4
# 1    GSW  6/2/19  GSW @ TOR     W    240    109     38     82      46.3
#
#    A_3PM    ...      A_AST  A_STL  A_BLK  A_TOV  A_PF  A_+/  A_EFGPerc  \
# 0     17    ...         30      9     10     14    22  14.0   0.628049
# 1     13    ...         34      7      5     15    26   5.0   0.542683
#
#       A_FTR  A_TOVPerc  Away_Team
# 0  0.256098  13.302927        TOR
# 1  0.280488  14.002987        GSW
#
# [2 rows x 28 columns]

# %%
home.count()
# Out:
# H_TEAM          11348
# DATE            11348
# MATCHUP         11348
# W/L             11348
# MIN             11348
# H_PTS           11348
# H_FGM           11348
# H_FGA           11348
# H_FGPerc        11348
# H_3PM           11348
# H_3PA           11348
# H_ThreePPerc    11348
# H_FTM           11348
# H_FTA           11348
# H_FTPerc        11348
# H_OREB          11348
# H_DREB          11348
# H_REB           11348
# H_AST           11348
# H_STL           11348
# H_BLK           11348
# H_TOV           11348
# H_PF            11348
# H_+/            11348
# H_EFGPerc       11348
# H_FTR           11348
# H_TOVPerc       11348
# Away_Team       11348
# dtype: int64

# %%
# inner joining ot make a new dataframe
new_df = pd.merge(home, away,left_on=[home['DATE'], home['Away_Team']], right_on=[away['DATE'], away['Away_Team']], how='inner')

# %%
new_df.columns
# Out:
# Index(['key_0', 'key_1', 'H_TEAM', 'DATE_x', 'MATCHUP_x', 'W/L', 'MIN',
#        'H_PTS', 'H_FGM', 'H_FGA', 'H_FGPerc', 'H_3PM', 'H_3PA', 'H_ThreePPerc',
#        'H_FTM', 'H_FTA', 'H_FTPerc', 'H_OREB', 'H_DREB', 'H_REB', 'H_AST',
#        'H_STL', 'H_BLK', 'H_TOV', 'H_PF', 'H_+/', 'H_EFGPerc', 'H_FTR',
#        'H_TOVPerc', 'Away_Team_x', 'A_TEAM', 'DATE_y', 'MATCHUP_y', 'A_W/L',
#        'A_MIN', 'A_PTS', 'A_FGM', 'A_FGA', 'A_FGPerc', 'A_3PM', 'A_3PA',
#        'A_ThreePPerc', 'A_FTM', 'A_FTA', 'A_FTPerc', 'A_OREB', 'A_DREB',
#        'A_REB', 'A_AST', 'A_STL', 'A_BLK', 'A_TOV', 'A_PF', 'A_+/',
#        'A_EFGPerc', 'A_FTR', 'A_TOVPerc', 'Away_Team_y'],
#       dtype='object')

# %%
new_df
# Out:
#           key_0 key_1 H_TEAM    DATE_x    MATCHUP_x W/L  MIN  H_PTS  H_FGM  \
# 0        6/5/19   TOR    GSW    6/5/19  GSW vs. TOR   L  241    109     36
# 1        6/2/19   GSW    TOR    6/2/19  TOR vs. GSW   L  240    104     35
# 2       5/30/19   GSW    TOR   5/30/19  TOR vs. GSW   W  241    118     39
# 3       5/25/19   MIL    TOR   5/25/19  TOR vs. MIL   W  239    100     36
# 4       5/23/19   TOR    MIL   5/23/19  MIL vs. TOR   L  240     99     38
# 5       5/21/19   MIL    TOR   5/21/19  TOR vs. MIL   W  239    120     41
# 6       5/20/19   GSW    POR   5/20/19  POR vs. GSW   L  265    117     47
# 7       5/19/19   MIL    TOR   5/19/19  TOR vs. MIL   W  290    118     40
# 8       5/18/19   GSW    POR   5/18/19  POR vs. GSW   L  239     99     34
# 9       5/17/19   TOR    MIL   5/17/19  MIL vs. TOR   W  240    125     43
# 10      5/16/19   POR    GSW   5/16/19  GSW vs. POR   W  242    114     42
# 11      5/15/19   TOR    MIL   5/15/19  MIL vs. TOR   W  241    108     37
# 12      5/14/19   POR    GSW   5/14/19  GSW vs. POR   W  240    116     42
# 13      5/12/19   POR    DEN   5/12/19  DEN vs. POR   L  240     96     33
# 14      5/12/19   PHI    TOR   5/12/19  TOR vs. PHI   W  239     92     34
# 15      5/10/19   GSW    HOU   5/10/19  HOU vs. GSW   L  240    113     42
# 16       5/9/19   TOR    PHI    5/9/19  PHI vs. TOR   W  243    112     41
# 17       5/9/19   DEN    POR    5/9/19  POR vs. DEN   W  241    119     41
# 18       5/8/19   HOU    GSW    5/8/19  GSW vs. HOU   W  240    104     39
# 19       5/8/19   BOS    MIL    5/8/19  MIL vs. BOS   W  240    116     42
# 20       5/7/19   POR    DEN    5/7/19  DEN vs. POR   W  239    124     44
# 21       5/7/19   PHI    TOR    5/7/19  TOR vs. PHI   W  240    125     40
# 22       5/6/19   MIL    BOS    5/6/19  BOS vs. MIL   L  240    101     34
# 23       5/6/19   GSW    HOU    5/6/19  HOU vs. GSW   W  239    112     39
# 24       5/5/19   TOR    PHI    5/5/19  PHI vs. TOR   L  239     96     33
# 25       5/5/19   DEN    POR    5/5/19  POR vs. DEN   L  240    112     39
# 26       5/4/19   GSW    HOU    5/4/19  HOU vs. GSW   W  265    126     45
# 27       5/3/19   MIL    BOS    5/3/19  BOS vs. MIL   L  240    116     35
# 28       5/3/19   DEN    POR    5/3/19  POR vs. DEN   W  340    140     52
# 29       5/2/19   TOR    PHI    5/2/19  PHI vs. TOR   W  239    116     43
# ...         ...   ...    ...       ...          ...  ..  ...    ...    ...
# 14179  10/12/12   OKC    UTA  10/12/12  UTA vs. OKC   W  239     97     34
# 14180  10/12/12   POR    PHX  10/12/12  PHX vs. POR   W  240    104     42
# 14181  10/12/12   NOH    HOU  10/12/12  HOU vs. NOH   W  240     95     37
# 14182  10/12/12   CLE    CHI  10/12/12  CHI vs. CLE   L  241     83     30
# 14183  10/12/12   MIN    IND  10/12/12  IND vs. MIN   W  240     96     41
# 14184  10/12/12   DEN    SAS  10/12/12  SAS vs. DEN   L  241     91     33
# 14185  10/11/12   NOH    CHA  10/11/12  CHA vs. NOH   L  241     87     30
# 14186  10/11/12   MAC    GSW  10/11/12  GSW vs. MAC   W  239    108     40
# 14187  10/11/12   PHI    ORL  10/11/12  ORL vs. PHI   L  241     95     42
# 14188  10/11/12   MIA    LAC  10/11/12  LAC vs. MIA   L  239     80     31
# 14189  10/11/12   NYK    WAS  10/11/12  WAS vs. NYK   L  241    101     33
# 14190  10/10/12   ATL    SAS  10/10/12  SAS vs. ATL   W  241    101     40
# 14191  10/10/12   PHX    SAC  10/10/12  SAC vs. PHX   W  241    102     35
# 14192  10/10/12   IND    MIN  10/10/12  MIN vs. IND   W  240     84     30
# 14193  10/10/12   OKC    HOU  10/10/12  HOU vs. OKC   W  241    107     37
# 14194  10/10/12   TOR    DET  10/10/12  DET vs. TOR   W  240    101     41
# 14195  10/10/12   POR    LAL  10/10/12  LAL vs. POR   L  242     75     27
# 14196   10/9/12   MIL    CLE   10/9/12  CLE vs. MIL   L  239     80     30
# 14197   10/9/12   CHA    NOH   10/9/12  NOH vs. CHA   W  239     97     38
# 14198   10/9/12   MEM    CHI   10/9/12  CHI vs. MEM   W  240     92     30
# 14199   10/9/12   DAL    FCB   10/9/12  FCB vs. DAL   W  239     99     32
# 14200   10/8/12   UTA    GSW   10/8/12  GSW vs. UTA   W  240     83     37
# 14201   10/8/12   RMD    TOR   10/8/12  TOR vs. RMD   W  238    102     39
# 14202   10/8/12   MPS    CLE   10/8/12  CLE vs. MPS   W  239     91     33
# 14203   10/7/12   GSW    LAL   10/7/12  LAL vs. GSW   L  242     83     28
# 14204   10/7/12   ORL    NOH   10/7/12  NOH vs. ORL   W  240     85     29
# 14205   10/7/12   WAS    CHA   10/7/12  CHA vs. WAS   W  239    100     32
# 14206   10/7/12   BOS    EAM   10/7/12  EAM vs. BOS   L  239     75     26
# 14207   10/7/12   MIA    ATL   10/7/12  ATL vs. MIA   W  241     92     33
# 14208   10/6/12   DEN    LAC   10/6/12  LAC vs. DEN   L  239    104     43
#
#        H_FGA     ...       A_AST  A_STL  A_BLK  A_TOV  A_PF  A_+/  A_EFGPerc  \
# 0         91     ...          30      9     10     14    22  14.0   0.628049
# 1         94     ...          34      7      5     15    26   5.0   0.542683
# 2         77     ...          29      6      2     16    27  -9.0   0.512821
# 3         74     ...          19      7      7     11    22  -6.0   0.480000
# 4         84     ...          19      6      4      6    16   6.0   0.476190
# 5         87     ...          30      8      7     12    22 -18.0   0.531250
# 6         98     ...          30     10      5     15    17   2.0   0.525253
# 7        102     ...          22     14      5     20    30  -6.0   0.441176
# 8         85     ...          27      9      5     13    24  11.0   0.535714
# 9         92     ...          19      3      6     13    30 -22.0   0.482759
# 10        82     ...          23      8      1     13    22  -3.0   0.546512
# 11        93     ...          17      9      4     12    21  -8.0   0.451087
# 12        84     ...          21      5      5     21    16 -22.0   0.403614
# 13        89     ...          16      5      7      4    31   4.0   0.430108
# 14        89     ...          16      4      7     15    21  -2.0   0.500000
# 15        89     ...          25      9      7     17    19   5.0   0.588235
# 16        89     ...          25      9      4     12    24 -11.0   0.487654
# 17        89     ...          22      7      3      6    23 -11.0   0.453488
# 18        85     ...          19     10      3     15    20  -5.0   0.493671
# 19        94     ...          19      9      1     14    18 -25.0   0.349462
# 20        89     ...          19      6      5      6    23 -26.0   0.418367
# 21        82     ...          19      6      5     19    26 -36.0   0.455696
# 22        90     ...          25      4      5      7    25  12.0   0.480000
# 23        89     ...          24      6      2     11    21  -4.0   0.511111
# 24        82     ...          19      6      3     13    24   5.0   0.526316
# 25        82     ...          21      7      4      8    22   4.0   0.494565
# 26        93     ...          27      6      6      8    22  -5.0   0.515789
# 27        81     ...          23      8      7     15    26   7.0   0.596386
# 28       124     ...          28     11      8     20    27  -3.0   0.516807
# 29        84     ...          15      7      4      9    17 -21.0   0.463855
# ...      ...     ...         ...    ...    ...    ...   ...   ...        ...
# 14179     81     ...          16     10      6     21    27 -16.0   0.391026
# 14180     82     ...          19      9      4     17    18 -11.0   0.431818
# 14181     75     ...          17      8      5     18    19 -20.0   0.385542
# 14182     86     ...          17     10      3     24    28   3.0   0.479452
# 14183     94     ...          19      9     13     18    18  -5.0   0.520548
# 14184     78     ...          16     12      3     24    27   6.0   0.475610
# 14185     76     ...          19      4      5     21    26   3.0   0.486301
# 14186     78     ...          23      9      5     13    22  -8.0   0.480519
# 14187     93     ...          17      5      4     15    14   7.0   0.500000
# 14188     72     ...          19     12      6     12    28  14.0   0.474026
# 14189     78     ...          26      8      0     15    25   7.0   0.597222
# 14190     77     ...          23     11      3     13    22  -2.0   0.425532
# 14191     86     ...          24      6      6     17    21  -6.0   0.454023
# 14192     74     ...          14      7      4     24    27 -14.0   0.386364
# 14193     86     ...          22     11      5     15    27  -2.0   0.516667
# 14194     81     ...          20     11      5     15    26  -2.0   0.547297
# 14195     71     ...          23      8      5     15    21  18.0   0.488235
# 14196     78     ...          22     11      8     12    16  17.0   0.476190
# 14197     87     ...          18      5      9     19    19 -15.0   0.493333
# 14198     84     ...          21     12      3     22    28  -4.0   0.433735
# 14199     79     ...          14      9      2     13    24 -14.0   0.418750
# 14200     79     ...          20      6      6     18    17  -3.0   0.406250
# 14201     89     ...          24      5      6     21    29  -7.0   0.492537
# 14202     67     ...          18      9      4     18    24  -6.0   0.419753
# 14203     71     ...          21      5      5     14    22  27.0   0.623288
# 14204     78     ...          20      8      2     20    29  -5.0   0.402778
# 14205     71     ...          14     11      4     20    31 -12.0   0.363636
# 14206     83     ...          19      7      6     14    23  30.0   0.559211
# 14207     80     ...          20     10      2     22    23 -13.0   0.485915
# 14208     84     ...          25     13      3     26    24   2.0   0.584416
#
#           A_FTR  A_TOVPerc  Away_Team_y
# 0      0.256098  13.302927          TOR
# 1      0.280488  14.002987          GSW
# 2      0.397436  14.864363          GSW
# 3      0.413333  11.039743          MIL
# 4      0.369048   5.789271          TOR
# 5      0.325000  11.600928          MIL
# 6      0.191919  12.258908          GSW
# 7      0.323529  14.649868          MIL
# 8      0.273810  12.135922          GSW
# 9      0.287356  11.711712          TOR
# 10     0.209302  12.158623          POR
# 11     0.217391  10.638298          TOR
# 12     0.373494  17.851071          POR
# 13     0.258065   3.718855          POR
# 14     0.461538  16.094421          PHI
# 15     0.270588  15.162326          GSW
# 16     0.358025  11.346445          TOR
# 17     0.372093   5.656109          DEN
# 18     0.303797  14.345830          HOU
# 19     0.365591  11.479173          BOS
# 20     0.306122   5.119454          POR
# 21     0.253165  17.790262          PHI
# 22     0.250000   5.932203          MIL
# 23     0.255556   9.899208          GSW
# 24     0.342105  12.943051          TOR
# 25     0.304348   7.122507          DEN
# 26     0.305263   6.910850          GSW
# 27     0.433735  13.176388          MIL
# 28     0.168067  13.531800          DEN
# 29     0.277108   8.813161          TOR
# ...         ...        ...          ...
# 14179  0.358974  18.864535          OKC
# 14180  0.227273  14.938489          POR
# 14181  0.192771  16.660496          NOH
# 14182  0.328767  22.313128          CLE
# 14183  0.273973  18.036072          MIN
# 14184  0.390244  19.986676          DEN
# 14185  0.328767  20.084162          NOH
# 14186  0.441558  12.385671          MAC
# 14187  0.235294  13.786765          PHI
# 14188  0.337662  11.947431          MIA
# 14189  0.388889  15.102698          NYK
# 14190  0.244681  11.099727          ATL
# 14191  0.298851  14.726265          PHX
# 14192  0.378788  23.762376          IND
# 14193  0.155556  13.494063          OKC
# 14194  0.378378  14.804580          TOR
# 14195  0.141176  14.247720          POR
# 14196  0.226190  11.498658          MIL
# 14197  0.200000  18.886680          CHA
# 14198  0.325301  18.822724          MEM
# 14199  0.400000  12.140456          DAL
# 14200  0.250000  16.853933          UTA
# 14201  0.656716  19.560358          RMD
# 14202  0.271605  16.562385          MPS
# 14203  0.438356  13.850416          GSW
# 14204  0.388889  19.171779          ORL
# 14205  0.212121  15.595758          WAS
# 14206  0.381579  13.623978          BOS
# 14207  0.225352  21.991204          MIA
# 14208  0.337662  22.719329          DEN
#
# [14209 rows x 58 columns]

# %%
new_df.count()
# Out:
# key_0           14209
# key_1           14209
# H_TEAM          14209
# DATE_x          14209
# MATCHUP_x       14209
# W/L             14209
# MIN             14209
# H_PTS           14209
# H_FGM           14209
# H_FGA           14209
# H_FGPerc        14209
# H_3PM           14209
# H_3PA           14209
# H_ThreePPerc    14209
# H_FTM           14209
# H_FTA           14209
# H_FTPerc        14209
# H_OREB          14209
# H_DREB          14209
# H_REB           14209
# H_AST           14209
# H_STL           14209
# H_BLK           14209
# H_TOV           14209
# H_PF            14209
# H_+/            14209
# H_EFGPerc       14209
# H_FTR           14209
# H_TOVPerc       14209
# Away_Team_x     14209
# A_TEAM          14209
# DATE_y          14209
# MATCHUP_y       14209
# A_W/L           14209
# A_MIN           14209
# A_PTS           14209
# A_FGM           14209
# A_FGA           14209
# A_FGPerc        14209
# A_3PM           14209
# A_3PA           14209
# A_ThreePPerc    14209
# A_FTM           14209
# A_FTA           14209
# A_FTPerc        14209
# A_OREB          14209
# A_DREB          14209
# A_REB           14209
# A_AST           14209
# A_STL           14209
# A_BLK           14209
# A_TOV           14209
# A_PF            14209
# A_+/            14209
# A_EFGPerc       14209
# A_FTR           14209
# A_TOVPerc       14209
# Away_Team_y     14209
# dtype: int64

# %%
# export working dataframe to csv
new_df.to_csv('csv_files/Home_Away_Combined.csv')
