# %%
# Importing the necessary packages
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading in the data set
home =pd.read_csv('csv_files/home_teams.csv', header=0)
away =pd.read_csv('csv_files/away_teams.csv', header=0)

# %%
# Dropping the unnamed column 
home = home.drop(['Unnamed: 0'], axis=1)

# %%
home.columns
# Out:
# Index(['TEAM', 'DATE', 'MATCHUP', 'W/L', 'MIN', 'PTS', 'FGM', 'FGA', 'FGPerc',
#        '3PM', '3PA', 'ThreePPerc', 'FTM', 'FTA', 'FTPerc', 'OREB', 'DREB',
#        'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', '+/', 'EFGPerc', 'FTR',
#        'TOVPerc'],
#       dtype='object')

# %%
# Renaming the columns in to make them all home orientated 
home.rename(columns={'TEAM':'H_TEAM','PTS':'H_PTS','FGM':'H_FGM','FGA':'H_FGA', 'FGPerc':'H_FGPerc', 
                    '3PM':'H_3PM', '3PA':'H_3PA', 'ThreePPerc':'H_ThreePPerc', 'FTM':'H_FTM', 'FTA':'H_FTA', 
                    'FTPerc':'H_FTPerc', 'OREB':'H_OREB', 'DREB':'H_DREB', 'REB':'H_REB', 'AST':'H_AST',
                    'STL':'H_STL', 'BLK':'H_BLK', 'TOV':'H_TOV', 'PF':'H_PF', '+/':'H_+/', 'EFGPerc':'H_EFGPerc',
                    'FTR':'H_FTR', 'TOVPerc':'H_TOVPerc'}, inplace=True)

# %%
away = away.drop(['Unnamed: 0'], axis=1)

# %%
# Renaming the columns in to make them all away orientated 
away.rename(columns={'TEAM':'A_TEAM','W/L':'A_W/L','MIN':'A_MIN','PTS':'A_PTS','FGM':'A_FGM','FGA':'A_FGA', 'FGPerc':'A_FGPerc', 
                    '3PM':'A_3PM', '3PA':'A_3PA', 'ThreePPerc':'A_ThreePPerc', 'FTM':'A_FTM', 'FTA':'A_FTA', 
                    'FTPerc':'A_FTPerc', 'OREB':'A_OREB', 'DREB':'A_DREB', 'REB':'A_REB', 'AST':'A_AST',
                    'STL':'A_STL', 'BLK':'A_BLK', 'TOV':'A_TOV', 'PF':'A_PF', '+/':'A_+/', 'EFGPerc':'A_EFGPerc',
                    'FTR':'A_FTR', 'TOVPerc':'A_TOVPerc'}, inplace=True)

# %%
away.columns
# Out:
# Index(['A_TEAM', 'DATE', 'MATCHUP', 'A_W/L', 'A_MIN', 'A_PTS', 'A_FGM',
#        'A_FGA', 'A_FGPerc', 'A_3PM', 'A_3PA', 'A_ThreePPerc', 'A_FTM', 'A_FTA',
#        'A_FTPerc', 'A_OREB', 'A_DREB', 'A_REB', 'A_AST', 'A_STL', 'A_BLK',
#        'A_TOV', 'A_PF', 'A_+/', 'A_EFGPerc', 'A_FTR', 'A_TOVPerc'],
#       dtype='object')

# %%
home.count()
# Out:
# H_TEAM          11348
# DATE            11348
# MATCHUP         11348
# W/L             11348
# MIN             11348
# H_PTS           11348
# H_FGM           11348
# H_FGA           11348
# H_FGPerc        11348
# H_3PM           11348
# H_3PA           11348
# H_ThreePPerc    11348
# H_FTM           11348
# H_FTA           11348
# H_FTPerc        11348
# H_OREB          11348
# H_DREB          11348
# H_REB           11348
# H_AST           11348
# H_STL           11348
# H_BLK           11348
# H_TOV           11348
# H_PF            11348
# H_+/            11348
# H_EFGPerc       11348
# H_FTR           11348
# H_TOVPerc       11348
# dtype: int64

# %%
# Creating an idential Away Team Variable to join the datasets on 
home['Away_Team'] = home['MATCHUP'].str[-3:]

# %%
# Creating an idential Away Team Variable to join the datasets on 
away['Away_Team'] = away['MATCHUP'].str[:3]

# %%
away.count()
# Out:
# A_TEAM          11347
# DATE            11347
# MATCHUP         11347
# A_W/L           11347
# A_MIN           11347
# A_PTS           11347
# A_FGM           11347
# A_FGA           11347
# A_FGPerc        11347
# A_3PM           11347
# A_3PA           11347
# A_ThreePPerc    11347
# A_FTM           11347
# A_FTA           11347
# A_FTPerc        11347
# A_OREB          11347
# A_DREB          11347
# A_REB           11347
# A_AST           11347
# A_STL           11347
# A_BLK           11347
# A_TOV           11347
# A_PF            11347
# A_+/            11347
# A_EFGPerc       11347
# A_FTR           11347
# A_TOVPerc       11347
# Away_Team       11347
# dtype: int64

# %%
home.count()
# Out:
# H_TEAM          11348
# DATE            11348
# MATCHUP         11348
# W/L             11348
# MIN             11348
# H_PTS           11348
# H_FGM           11348
# H_FGA           11348
# H_FGPerc        11348
# H_3PM           11348
# H_3PA           11348
# H_ThreePPerc    11348
# H_FTM           11348
# H_FTA           11348
# H_FTPerc        11348
# H_OREB          11348
# H_DREB          11348
# H_REB           11348
# H_AST           11348
# H_STL           11348
# H_BLK           11348
# H_TOV           11348
# H_PF            11348
# H_+/            11348
# H_EFGPerc       11348
# H_FTR           11348
# H_TOVPerc       11348
# Away_Team       11348
# dtype: int64

# %%
# inner joining ot make a new dataframe
new_df = pd.merge(home, away,left_on=[home['DATE'], home['Away_Team']], right_on=[away['DATE'], away['Away_Team']], how='inner')

# %%
new_df.columns
# Out:
# Index(['key_0', 'key_1', 'H_TEAM', 'DATE_x', 'MATCHUP_x', 'W/L', 'MIN',
#        'H_PTS', 'H_FGM', 'H_FGA', 'H_FGPerc', 'H_3PM', 'H_3PA', 'H_ThreePPerc',
#        'H_FTM', 'H_FTA', 'H_FTPerc', 'H_OREB', 'H_DREB', 'H_REB', 'H_AST',
#        'H_STL', 'H_BLK', 'H_TOV', 'H_PF', 'H_+/', 'H_EFGPerc', 'H_FTR',
#        'H_TOVPerc', 'Away_Team_x', 'A_TEAM', 'DATE_y', 'MATCHUP_y', 'A_W/L',
#        'A_MIN', 'A_PTS', 'A_FGM', 'A_FGA', 'A_FGPerc', 'A_3PM', 'A_3PA',
#        'A_ThreePPerc', 'A_FTM', 'A_FTA', 'A_FTPerc', 'A_OREB', 'A_DREB',
#        'A_REB', 'A_AST', 'A_STL', 'A_BLK', 'A_TOV', 'A_PF', 'A_+/',
#        'A_EFGPerc', 'A_FTR', 'A_TOVPerc', 'Away_Team_y'],
#       dtype='object')

# %%
new_df
# Out:
#           key_0 key_1 H_TEAM    DATE_x    MATCHUP_x W/L  MIN  H_PTS  H_FGM  \
# 0        6/5/19   TOR    GSW    6/5/19  GSW vs. TOR   L  241    109     36
# 1        6/2/19   GSW    TOR    6/2/19  TOR vs. GSW   L  240    104     35
# 2       5/30/19   GSW    TOR   5/30/19  TOR vs. GSW   W  241    118     39
# 3       5/25/19   MIL    TOR   5/25/19  TOR vs. MIL   W  239    100     36
# 4       5/23/19   TOR    MIL   5/23/19  MIL vs. TOR   L  240     99     38
# 5       5/21/19   MIL    TOR   5/21/19  TOR vs. MIL   W  239    120     41
# 6       5/20/19   GSW    POR   5/20/19  POR vs. GSW   L  265    117     47
# 7       5/19/19   MIL    TOR   5/19/19  TOR vs. MIL   W  290    118     40
# 8       5/18/19   GSW    POR   5/18/19  POR vs. GSW   L  239     99     34
# 9       5/17/19   TOR    MIL   5/17/19  MIL vs. TOR   W  240    125     43
# 10      5/16/19   POR    GSW   5/16/19  GSW vs. POR   W  242    114     42
# 11      5/15/19   TOR    MIL   5/15/19  MIL vs. TOR   W  241    108     37
# 12      5/14/19   POR    GSW   5/14/19  GSW vs. POR   W  240    116     42
# 13      5/12/19   POR    DEN   5/12/19  DEN vs. POR   L  240     96     33
# 14      5/12/19   PHI    TOR   5/12/19  TOR vs. PHI   W  239     92     34
# 15      5/10/19   GSW    HOU   5/10/19  HOU vs. GSW   L  240    113     42
# 16       5/9/19   TOR    PHI    5/9/19  PHI vs. TOR   W  243    112     41
# 17       5/9/19   DEN    POR    5/9/19  POR vs. DEN   W  241    119     41
# 18       5/8/19   HOU    GSW    5/8/19  GSW vs. HOU   W  240    104     39
# 19       5/8/19   BOS    MIL    5/8/19  MIL vs. BOS   W  240    116     42
# 20       5/7/19   POR    DEN    5/7/19  DEN vs. POR   W  239    124     44
# 21       5/7/19   PHI    TOR    5/7/19  TOR vs. PHI   W  240    125     40
# 22       5/6/19   MIL    BOS    5/6/19  BOS vs. MIL   L  240    101     34
# 23       5/6/19   GSW    HOU    5/6/19  HOU vs. GSW   W  239    112     39
# 24       5/5/19   TOR    PHI    5/5/19  PHI vs. TOR   L  239     96     33
# 25       5/5/19   DEN    POR    5/5/19  POR vs. DEN   L  240    112     39
# 26       5/4/19   GSW    HOU    5/4/19  HOU vs. GSW   W  265    126     45
# 27       5/3/19   MIL    BOS    5/3/19  BOS vs. MIL   L  240    116     35
# 28       5/3/19   DEN    POR    5/3/19  POR vs. DEN   W  340    140     52
# 29       5/2/19   TOR    PHI    5/2/19  PHI vs. TOR   W  239    116     43
# ...         ...   ...    ...       ...          ...  ..  ...    ...    ...
# 14179  10/12/12   OKC    UTA  10/12/12  UTA vs. OKC   W  239     97     34
# 14180  10/12/12   POR    PHX  10/12/12  PHX vs. POR   W  240    104     42
# 14181  10/12/12   NOH    HOU  10/12/12  HOU vs. NOH   W  240     95     37
# 14182  10/12/12   CLE    CHI  10/12/12  CHI vs. CLE   L  241     83     30
# 14183  10/12/12   MIN    IND  10/12/12  IND vs. MIN   W  240     96     41
# 14184  10/12/12   DEN    SAS  10/12/12  SAS vs. DEN   L  241     91     33
# 14185  10/11/12   NOH    CHA  10/11/12  CHA vs. NOH   L  241     87     30
# 14186  10/11/12   MAC    GSW  10/11/12  GSW vs. MAC   W  239    108     40
# 14187  10/11/12   PHI    ORL  10/11/12  ORL vs. PHI   L  241     95     42
# 14188  10/11/12   MIA    LAC  10/11/12  LAC vs. MIA   L  239     80     31
# 14189  10/11/12   NYK    WAS  10/11/12  WAS vs. NYK   L  241    101     33
# 14190  10/10/12   ATL    SAS  10/10/12  SAS vs. ATL   W  241    101     40
# 14191  10/10/12   PHX    SAC  10/10/12  SAC vs. PHX   W  241    102     35
# 14192  10/10/12   IND    MIN  10/10/12  MIN vs. IND   W  240     84     30
# 14193  10/10/12   OKC    HOU  10/10/12  HOU vs. OKC   W  241    107     37
# 14194  10/10/12   TOR    DET  10/10/12  DET vs. TOR   W  240    101     41
# 14195  10/10/12   POR    LAL  10/10/12  LAL vs. POR   L  242     75     27
# 14196   10/9/12   MIL    CLE   10/9/12  CLE vs. MIL   L  239     80     30
# 14197   10/9/12   CHA    NOH   10/9/12  NOH vs. CHA   W  239     97     38
# 14198   10/9/12   MEM    CHI   10/9/12  CHI vs. MEM   W  240     92     30
# 14199   10/9/12   DAL    FCB   10/9/12  FCB vs. DAL   W  239     99     32
# 14200   10/8/12   UTA    GSW   10/8/12  GSW vs. UTA   W  240     83     37
# 14201   10/8/12   RMD    TOR   10/8/12  TOR vs. RMD   W  238    102     39
# 14202   10/8/12   MPS    CLE   10/8/12  CLE vs. MPS   W  239     91     33
# 14203   10/7/12   GSW    LAL   10/7/12  LAL vs. GSW   L  242     83     28
# 14204   10/7/12   ORL    NOH   10/7/12  NOH vs. ORL   W  240     85     29
# 14205   10/7/12   WAS    CHA   10/7/12  CHA vs. WAS   W  239    100     32
# 14206   10/7/12   BOS    EAM   10/7/12  EAM vs. BOS   L  239     75     26
# 14207   10/7/12   MIA    ATL   10/7/12  ATL vs. MIA   W  241     92     33
# 14208   10/6/12   DEN    LAC   10/6/12  LAC vs. DEN   L  239    104     43
#
#        H_FGA     ...       A_AST  A_STL  A_BLK  A_TOV  A_PF  A_+/  A_EFGPerc  \
# 0         91     ...          30      9     10     14    22  14.0   0.628049
# 1         94     ...          34      7      5     15    26   5.0   0.542683
# 2         77     ...          29      6      2     16    27  -9.0   0.512821
# 3         74     ...          19      7      7     11    22  -6.0   0.480000
# 4         84     ...          19      6      4      6    16   6.0   0.476190
# 5         87     ...          30      8      7     12    22 -18.0   0.531250
# 6         98     ...          30     10      5     15    17   2.0   0.525253
# 7        102     ...          22     14      5     20    30  -6.0   0.441176
# 8         85     ...          27      9      5     13    24  11.0   0.535714
# 9         92     ...          19      3      6     13    30 -22.0   0.482759
# 10        82     ...          23      8      1     13    22  -3.0   0.546512
# 11        93     ...          17      9      4     12    21  -8.0   0.451087
# 12        84     ...          21      5      5     21    16 -22.0   0.403614
# 13        89     ...          16      5      7      4    31   4.0   0.430108
# 14        89     ...          16      4      7     15    21  -2.0   0.500000
# 15        89     ...          25      9      7     17    19   5.0   0.588235
# 16        89     ...          25      9      4     12    24 -11.0   0.487654
# 17        89     ...          22      7      3      6    23 -11.0   0.453488
# 18        85     ...          19     10      3     15    20  -5.0   0.493671
# 19        94     ...          19      9      1     14    18 -25.0   0.349462
# 20        89     ...          19      6      5      6    23 -26.0   0.418367
# 21        82     ...          19      6      5     19    26 -36.0   0.455696
# 22        90     ...          25      4      5      7    25  12.0   0.480000
# 23        89     ...          24      6      2     11    21  -4.0   0.511111
# 24        82     ...          19      6      3     13    24   5.0   0.526316
# 25        82     ...          21      7      4      8    22   4.0   0.494565
# 26        93     ...          27      6      6      8    22  -5.0   0.515789
# 27        81     ...          23      8      7     15    26   7.0   0.596386
# 28       124     ...          28     11      8     20    27  -3.0   0.516807
# 29        84     ...          15      7      4      9    17 -21.0   0.463855
# ...      ...     ...         ...    ...    ...    ...   ...   ...        ...
# 14179     81     ...          16     10      6     21    27 -16.0   0.391026
# 14180     82     ...          19      9      4     17    18 -11.0   0.431818
# 14181     75     ...          17      8      5     18    19 -20.0   0.385542
# 14182     86     ...          17     10      3     24    28   3.0   0.479452
# 14183     94     ...          19      9     13     18    18  -5.0   0.520548
# 14184     78     ...          16     12      3     24    27   6.0   0.475610
# 14185     76     ...          19      4      5     21    26   3.0   0.486301
# 14186     78     ...          23      9      5     13    22  -8.0   0.480519
# 14187     93     ...          17      5      4     15    14   7.0   0.500000
# 14188     72     ...          19     12      6     12    28  14.0   0.474026
# 14189     78     ...          26      8      0     15    25   7.0   0.597222
# 14190     77     ...          23     11      3     13    22  -2.0   0.425532
# 14191     86     ...          24      6      6     17    21  -6.0   0.454023
# 14192     74     ...          14      7      4     24    27 -14.0   0.386364
# 14193     86     ...          22     11      5     15    27  -2.0   0.516667
# 14194     81     ...          20     11      5     15    26  -2.0   0.547297
# 14195     71     ...          23      8      5     15    21  18.0   0.488235
# 14196     78     ...          22     11      8     12    16  17.0   0.476190
# 14197     87     ...          18      5      9     19    19 -15.0   0.493333
# 14198     84     ...          21     12      3     22    28  -4.0   0.433735
# 14199     79     ...          14      9      2     13    24 -14.0   0.418750
# 14200     79     ...          20      6      6     18    17  -3.0   0.406250
# 14201     89     ...          24      5      6     21    29  -7.0   0.492537
# 14202     67     ...          18      9      4     18    24  -6.0   0.419753
# 14203     71     ...          21      5      5     14    22  27.0   0.623288
# 14204     78     ...          20      8      2     20    29  -5.0   0.402778
# 14205     71     ...          14     11      4     20    31 -12.0   0.363636
# 14206     83     ...          19      7      6     14    23  30.0   0.559211
# 14207     80     ...          20     10      2     22    23 -13.0   0.485915
# 14208     84     ...          25     13      3     26    24   2.0   0.584416
#
#           A_FTR  A_TOVPerc  Away_Team_y
# 0      0.256098  13.302927          TOR
# 1      0.280488  14.002987          GSW
# 2      0.397436  14.864363          GSW
# 3      0.413333  11.039743          MIL
# 4      0.369048   5.789271          TOR
# 5      0.325000  11.600928          MIL
# 6      0.191919  12.258908          GSW
# 7      0.323529  14.649868          MIL
# 8      0.273810  12.135922          GSW
# 9      0.287356  11.711712          TOR
# 10     0.209302  12.158623          POR
# 11     0.217391  10.638298          TOR
# 12     0.373494  17.851071          POR
# 13     0.258065   3.718855          POR
# 14     0.461538  16.094421          PHI
# 15     0.270588  15.162326          GSW
# 16     0.358025  11.346445          TOR
# 17     0.372093   5.656109          DEN
# 18     0.303797  14.345830          HOU
# 19     0.365591  11.479173          BOS
# 20     0.306122   5.119454          POR
# 21     0.253165  17.790262          PHI
# 22     0.250000   5.932203          MIL
# 23     0.255556   9.899208          GSW
# 24     0.342105  12.943051          TOR
# 25     0.304348   7.122507          DEN
# 26     0.305263   6.910850          GSW
# 27     0.433735  13.176388          MIL
# 28     0.168067  13.531800          DEN
# 29     0.277108   8.813161          TOR
# ...         ...        ...          ...
# 14179  0.358974  18.864535          OKC
# 14180  0.227273  14.938489          POR
# 14181  0.192771  16.660496          NOH
# 14182  0.328767  22.313128          CLE
# 14183  0.273973  18.036072          MIN
# 14184  0.390244  19.986676          DEN
# 14185  0.328767  20.084162          NOH
# 14186  0.441558  12.385671          MAC
# 14187  0.235294  13.786765          PHI
# 14188  0.337662  11.947431          MIA
# 14189  0.388889  15.102698          NYK
# 14190  0.244681  11.099727          ATL
# 14191  0.298851  14.726265          PHX
# 14192  0.378788  23.762376          IND
# 14193  0.155556  13.494063          OKC
# 14194  0.378378  14.804580          TOR
# 14195  0.141176  14.247720          POR
# 14196  0.226190  11.498658          MIL
# 14197  0.200000  18.886680          CHA
# 14198  0.325301  18.822724          MEM
# 14199  0.400000  12.140456          DAL
# 14200  0.250000  16.853933          UTA
# 14201  0.656716  19.560358          RMD
# 14202  0.271605  16.562385          MPS
# 14203  0.438356  13.850416          GSW
# 14204  0.388889  19.171779          ORL
# 14205  0.212121  15.595758          WAS
# 14206  0.381579  13.623978          BOS
# 14207  0.225352  21.991204          MIA
# 14208  0.337662  22.719329          DEN
#
# [14209 rows x 58 columns]

# %%
new_df.count()
# Out:
# key_0           14209
# key_1           14209
# H_TEAM          14209
# DATE_x          14209
# MATCHUP_x       14209
# W/L             14209
# MIN             14209
# H_PTS           14209
# H_FGM           14209
# H_FGA           14209
# H_FGPerc        14209
# H_3PM           14209
# H_3PA           14209
# H_ThreePPerc    14209
# H_FTM           14209
# H_FTA           14209
# H_FTPerc        14209
# H_OREB          14209
# H_DREB          14209
# H_REB           14209
# H_AST           14209
# H_STL           14209
# H_BLK           14209
# H_TOV           14209
# H_PF            14209
# H_+/            14209
# H_EFGPerc       14209
# H_FTR           14209
# H_TOVPerc       14209
# Away_Team_x     14209
# A_TEAM          14209
# DATE_y          14209
# MATCHUP_y       14209
# A_W/L           14209
# A_MIN           14209
# A_PTS           14209
# A_FGM           14209
# A_FGA           14209
# A_FGPerc        14209
# A_3PM           14209
# A_3PA           14209
# A_ThreePPerc    14209
# A_FTM           14209
# A_FTA           14209
# A_FTPerc        14209
# A_OREB          14209
# A_DREB          14209
# A_REB           14209
# A_AST           14209
# A_STL           14209
# A_BLK           14209
# A_TOV           14209
# A_PF            14209
# A_+/            14209
# A_EFGPerc       14209
# A_FTR           14209
# A_TOVPerc       14209
# Away_Team_y     14209
# dtype: int64

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14209 entries, 0 to 14208
# Data columns (total 58 columns):
# key_0           14209 non-null object
# key_1           14209 non-null object
# H_TEAM          14209 non-null object
# DATE_x          14209 non-null object
# MATCHUP_x       14209 non-null object
# W/L             14209 non-null object
# MIN             14209 non-null int64
# H_PTS           14209 non-null int64
# H_FGM           14209 non-null int64
# H_FGA           14209 non-null int64
# H_FGPerc        14209 non-null float64
# H_3PM           14209 non-null int64
# H_3PA           14209 non-null int64
# H_ThreePPerc    14209 non-null float64
# H_FTM           14209 non-null int64
# H_FTA           14209 non-null int64
# H_FTPerc        14209 non-null float64
# H_OREB          14209 non-null int64
# H_DREB          14209 non-null int64
# H_REB           14209 non-null int64
# H_AST           14209 non-null int64
# H_STL           14209 non-null int64
# H_BLK           14209 non-null int64
# H_TOV           14209 non-null int64
# H_PF            14209 non-null int64
# H_+/            14209 non-null float64
# H_EFGPerc       14209 non-null float64
# H_FTR           14209 non-null float64
# H_TOVPerc       14209 non-null float64
# Away_Team_x     14209 non-null object
# A_TEAM          14209 non-null object
# DATE_y          14209 non-null object
# MATCHUP_y       14209 non-null object
# A_W/L           14209 non-null object
# A_MIN           14209 non-null int64
# A_PTS           14209 non-null int64
# A_FGM           14209 non-null int64
# A_FGA           14209 non-null int64
# A_FGPerc        14209 non-null float64
# A_3PM           14209 non-null int64
# A_3PA           14209 non-null int64
# A_ThreePPerc    14209 non-null float64
# A_FTM           14209 non-null int64
# A_FTA           14209 non-null int64
# A_FTPerc        14209 non-null float64
# A_OREB          14209 non-null int64
# A_DREB          14209 non-null int64
# A_REB           14209 non-null int64
# A_AST           14209 non-null int64
# A_STL           14209 non-null int64
# A_BLK           14209 non-null int64
# A_TOV           14209 non-null int64
# A_PF            14209 non-null int64
# A_+/            14209 non-null float64
# A_EFGPerc       14209 non-null float64
# A_FTR           14209 non-null float64
# A_TOVPerc       14209 non-null float64
# Away_Team_y     14209 non-null object
# dtypes: float64(14), int64(32), object(12)
# memory usage: 6.4+ MB

# %%
new_df = new_df.drop_duplicates()

# %%
new_df
# Out:
#           key_0 key_1 H_TEAM    DATE_x    MATCHUP_x W/L  MIN  H_PTS  H_FGM  \
# 0        6/5/19   TOR    GSW    6/5/19  GSW vs. TOR   L  241    109     36
# 1        6/2/19   GSW    TOR    6/2/19  TOR vs. GSW   L  240    104     35
# 2       5/30/19   GSW    TOR   5/30/19  TOR vs. GSW   W  241    118     39
# 3       5/25/19   MIL    TOR   5/25/19  TOR vs. MIL   W  239    100     36
# 4       5/23/19   TOR    MIL   5/23/19  MIL vs. TOR   L  240     99     38
# 5       5/21/19   MIL    TOR   5/21/19  TOR vs. MIL   W  239    120     41
# 6       5/20/19   GSW    POR   5/20/19  POR vs. GSW   L  265    117     47
# 7       5/19/19   MIL    TOR   5/19/19  TOR vs. MIL   W  290    118     40
# 8       5/18/19   GSW    POR   5/18/19  POR vs. GSW   L  239     99     34
# 9       5/17/19   TOR    MIL   5/17/19  MIL vs. TOR   W  240    125     43
# 10      5/16/19   POR    GSW   5/16/19  GSW vs. POR   W  242    114     42
# 11      5/15/19   TOR    MIL   5/15/19  MIL vs. TOR   W  241    108     37
# 12      5/14/19   POR    GSW   5/14/19  GSW vs. POR   W  240    116     42
# 13      5/12/19   POR    DEN   5/12/19  DEN vs. POR   L  240     96     33
# 14      5/12/19   PHI    TOR   5/12/19  TOR vs. PHI   W  239     92     34
# 15      5/10/19   GSW    HOU   5/10/19  HOU vs. GSW   L  240    113     42
# 16       5/9/19   TOR    PHI    5/9/19  PHI vs. TOR   W  243    112     41
# 17       5/9/19   DEN    POR    5/9/19  POR vs. DEN   W  241    119     41
# 18       5/8/19   HOU    GSW    5/8/19  GSW vs. HOU   W  240    104     39
# 19       5/8/19   BOS    MIL    5/8/19  MIL vs. BOS   W  240    116     42
# 20       5/7/19   POR    DEN    5/7/19  DEN vs. POR   W  239    124     44
# 21       5/7/19   PHI    TOR    5/7/19  TOR vs. PHI   W  240    125     40
# 22       5/6/19   MIL    BOS    5/6/19  BOS vs. MIL   L  240    101     34
# 23       5/6/19   GSW    HOU    5/6/19  HOU vs. GSW   W  239    112     39
# 24       5/5/19   TOR    PHI    5/5/19  PHI vs. TOR   L  239     96     33
# 25       5/5/19   DEN    POR    5/5/19  POR vs. DEN   L  240    112     39
# 26       5/4/19   GSW    HOU    5/4/19  HOU vs. GSW   W  265    126     45
# 27       5/3/19   MIL    BOS    5/3/19  BOS vs. MIL   L  240    116     35
# 28       5/3/19   DEN    POR    5/3/19  POR vs. DEN   W  340    140     52
# 29       5/2/19   TOR    PHI    5/2/19  PHI vs. TOR   W  239    116     43
# ...         ...   ...    ...       ...          ...  ..  ...    ...    ...
# 14179  10/12/12   OKC    UTA  10/12/12  UTA vs. OKC   W  239     97     34
# 14180  10/12/12   POR    PHX  10/12/12  PHX vs. POR   W  240    104     42
# 14181  10/12/12   NOH    HOU  10/12/12  HOU vs. NOH   W  240     95     37
# 14182  10/12/12   CLE    CHI  10/12/12  CHI vs. CLE   L  241     83     30
# 14183  10/12/12   MIN    IND  10/12/12  IND vs. MIN   W  240     96     41
# 14184  10/12/12   DEN    SAS  10/12/12  SAS vs. DEN   L  241     91     33
# 14185  10/11/12   NOH    CHA  10/11/12  CHA vs. NOH   L  241     87     30
# 14186  10/11/12   MAC    GSW  10/11/12  GSW vs. MAC   W  239    108     40
# 14187  10/11/12   PHI    ORL  10/11/12  ORL vs. PHI   L  241     95     42
# 14188  10/11/12   MIA    LAC  10/11/12  LAC vs. MIA   L  239     80     31
# 14189  10/11/12   NYK    WAS  10/11/12  WAS vs. NYK   L  241    101     33
# 14190  10/10/12   ATL    SAS  10/10/12  SAS vs. ATL   W  241    101     40
# 14191  10/10/12   PHX    SAC  10/10/12  SAC vs. PHX   W  241    102     35
# 14192  10/10/12   IND    MIN  10/10/12  MIN vs. IND   W  240     84     30
# 14193  10/10/12   OKC    HOU  10/10/12  HOU vs. OKC   W  241    107     37
# 14194  10/10/12   TOR    DET  10/10/12  DET vs. TOR   W  240    101     41
# 14195  10/10/12   POR    LAL  10/10/12  LAL vs. POR   L  242     75     27
# 14196   10/9/12   MIL    CLE   10/9/12  CLE vs. MIL   L  239     80     30
# 14197   10/9/12   CHA    NOH   10/9/12  NOH vs. CHA   W  239     97     38
# 14198   10/9/12   MEM    CHI   10/9/12  CHI vs. MEM   W  240     92     30
# 14199   10/9/12   DAL    FCB   10/9/12  FCB vs. DAL   W  239     99     32
# 14200   10/8/12   UTA    GSW   10/8/12  GSW vs. UTA   W  240     83     37
# 14201   10/8/12   RMD    TOR   10/8/12  TOR vs. RMD   W  238    102     39
# 14202   10/8/12   MPS    CLE   10/8/12  CLE vs. MPS   W  239     91     33
# 14203   10/7/12   GSW    LAL   10/7/12  LAL vs. GSW   L  242     83     28
# 14204   10/7/12   ORL    NOH   10/7/12  NOH vs. ORL   W  240     85     29
# 14205   10/7/12   WAS    CHA   10/7/12  CHA vs. WAS   W  239    100     32
# 14206   10/7/12   BOS    EAM   10/7/12  EAM vs. BOS   L  239     75     26
# 14207   10/7/12   MIA    ATL   10/7/12  ATL vs. MIA   W  241     92     33
# 14208   10/6/12   DEN    LAC   10/6/12  LAC vs. DEN   L  239    104     43
#
#        H_FGA     ...       A_AST  A_STL  A_BLK  A_TOV  A_PF  A_+/  A_EFGPerc  \
# 0         91     ...          30      9     10     14    22  14.0   0.628049
# 1         94     ...          34      7      5     15    26   5.0   0.542683
# 2         77     ...          29      6      2     16    27  -9.0   0.512821
# 3         74     ...          19      7      7     11    22  -6.0   0.480000
# 4         84     ...          19      6      4      6    16   6.0   0.476190
# 5         87     ...          30      8      7     12    22 -18.0   0.531250
# 6         98     ...          30     10      5     15    17   2.0   0.525253
# 7        102     ...          22     14      5     20    30  -6.0   0.441176
# 8         85     ...          27      9      5     13    24  11.0   0.535714
# 9         92     ...          19      3      6     13    30 -22.0   0.482759
# 10        82     ...          23      8      1     13    22  -3.0   0.546512
# 11        93     ...          17      9      4     12    21  -8.0   0.451087
# 12        84     ...          21      5      5     21    16 -22.0   0.403614
# 13        89     ...          16      5      7      4    31   4.0   0.430108
# 14        89     ...          16      4      7     15    21  -2.0   0.500000
# 15        89     ...          25      9      7     17    19   5.0   0.588235
# 16        89     ...          25      9      4     12    24 -11.0   0.487654
# 17        89     ...          22      7      3      6    23 -11.0   0.453488
# 18        85     ...          19     10      3     15    20  -5.0   0.493671
# 19        94     ...          19      9      1     14    18 -25.0   0.349462
# 20        89     ...          19      6      5      6    23 -26.0   0.418367
# 21        82     ...          19      6      5     19    26 -36.0   0.455696
# 22        90     ...          25      4      5      7    25  12.0   0.480000
# 23        89     ...          24      6      2     11    21  -4.0   0.511111
# 24        82     ...          19      6      3     13    24   5.0   0.526316
# 25        82     ...          21      7      4      8    22   4.0   0.494565
# 26        93     ...          27      6      6      8    22  -5.0   0.515789
# 27        81     ...          23      8      7     15    26   7.0   0.596386
# 28       124     ...          28     11      8     20    27  -3.0   0.516807
# 29        84     ...          15      7      4      9    17 -21.0   0.463855
# ...      ...     ...         ...    ...    ...    ...   ...   ...        ...
# 14179     81     ...          16     10      6     21    27 -16.0   0.391026
# 14180     82     ...          19      9      4     17    18 -11.0   0.431818
# 14181     75     ...          17      8      5     18    19 -20.0   0.385542
# 14182     86     ...          17     10      3     24    28   3.0   0.479452
# 14183     94     ...          19      9     13     18    18  -5.0   0.520548
# 14184     78     ...          16     12      3     24    27   6.0   0.475610
# 14185     76     ...          19      4      5     21    26   3.0   0.486301
# 14186     78     ...          23      9      5     13    22  -8.0   0.480519
# 14187     93     ...          17      5      4     15    14   7.0   0.500000
# 14188     72     ...          19     12      6     12    28  14.0   0.474026
# 14189     78     ...          26      8      0     15    25   7.0   0.597222
# 14190     77     ...          23     11      3     13    22  -2.0   0.425532
# 14191     86     ...          24      6      6     17    21  -6.0   0.454023
# 14192     74     ...          14      7      4     24    27 -14.0   0.386364
# 14193     86     ...          22     11      5     15    27  -2.0   0.516667
# 14194     81     ...          20     11      5     15    26  -2.0   0.547297
# 14195     71     ...          23      8      5     15    21  18.0   0.488235
# 14196     78     ...          22     11      8     12    16  17.0   0.476190
# 14197     87     ...          18      5      9     19    19 -15.0   0.493333
# 14198     84     ...          21     12      3     22    28  -4.0   0.433735
# 14199     79     ...          14      9      2     13    24 -14.0   0.418750
# 14200     79     ...          20      6      6     18    17  -3.0   0.406250
# 14201     89     ...          24      5      6     21    29  -7.0   0.492537
# 14202     67     ...          18      9      4     18    24  -6.0   0.419753
# 14203     71     ...          21      5      5     14    22  27.0   0.623288
# 14204     78     ...          20      8      2     20    29  -5.0   0.402778
# 14205     71     ...          14     11      4     20    31 -12.0   0.363636
# 14206     83     ...          19      7      6     14    23  30.0   0.559211
# 14207     80     ...          20     10      2     22    23 -13.0   0.485915
# 14208     84     ...          25     13      3     26    24   2.0   0.584416
#
#           A_FTR  A_TOVPerc  Away_Team_y
# 0      0.256098  13.302927          TOR
# 1      0.280488  14.002987          GSW
# 2      0.397436  14.864363          GSW
# 3      0.413333  11.039743          MIL
# 4      0.369048   5.789271          TOR
# 5      0.325000  11.600928          MIL
# 6      0.191919  12.258908          GSW
# 7      0.323529  14.649868          MIL
# 8      0.273810  12.135922          GSW
# 9      0.287356  11.711712          TOR
# 10     0.209302  12.158623          POR
# 11     0.217391  10.638298          TOR
# 12     0.373494  17.851071          POR
# 13     0.258065   3.718855          POR
# 14     0.461538  16.094421          PHI
# 15     0.270588  15.162326          GSW
# 16     0.358025  11.346445          TOR
# 17     0.372093   5.656109          DEN
# 18     0.303797  14.345830          HOU
# 19     0.365591  11.479173          BOS
# 20     0.306122   5.119454          POR
# 21     0.253165  17.790262          PHI
# 22     0.250000   5.932203          MIL
# 23     0.255556   9.899208          GSW
# 24     0.342105  12.943051          TOR
# 25     0.304348   7.122507          DEN
# 26     0.305263   6.910850          GSW
# 27     0.433735  13.176388          MIL
# 28     0.168067  13.531800          DEN
# 29     0.277108   8.813161          TOR
# ...         ...        ...          ...
# 14179  0.358974  18.864535          OKC
# 14180  0.227273  14.938489          POR
# 14181  0.192771  16.660496          NOH
# 14182  0.328767  22.313128          CLE
# 14183  0.273973  18.036072          MIN
# 14184  0.390244  19.986676          DEN
# 14185  0.328767  20.084162          NOH
# 14186  0.441558  12.385671          MAC
# 14187  0.235294  13.786765          PHI
# 14188  0.337662  11.947431          MIA
# 14189  0.388889  15.102698          NYK
# 14190  0.244681  11.099727          ATL
# 14191  0.298851  14.726265          PHX
# 14192  0.378788  23.762376          IND
# 14193  0.155556  13.494063          OKC
# 14194  0.378378  14.804580          TOR
# 14195  0.141176  14.247720          POR
# 14196  0.226190  11.498658          MIL
# 14197  0.200000  18.886680          CHA
# 14198  0.325301  18.822724          MEM
# 14199  0.400000  12.140456          DAL
# 14200  0.250000  16.853933          UTA
# 14201  0.656716  19.560358          RMD
# 14202  0.271605  16.562385          MPS
# 14203  0.438356  13.850416          GSW
# 14204  0.388889  19.171779          ORL
# 14205  0.212121  15.595758          WAS
# 14206  0.381579  13.623978          BOS
# 14207  0.225352  21.991204          MIA
# 14208  0.337662  22.719329          DEN
#
# [9922 rows x 58 columns]

# %%
# export working dataframe to csv
new_df.to_csv('csv_files/Home_Away_Combined.csv')

# %%
new_df.columns
# Out:
# Index(['key_0', 'key_1', 'H_TEAM', 'DATE_x', 'MATCHUP_x', 'W/L', 'MIN',
#        'H_PTS', 'H_FGM', 'H_FGA', 'H_FGPerc', 'H_3PM', 'H_3PA', 'H_ThreePPerc',
#        'H_FTM', 'H_FTA', 'H_FTPerc', 'H_OREB', 'H_DREB', 'H_REB', 'H_AST',
#        'H_STL', 'H_BLK', 'H_TOV', 'H_PF', 'H_+/', 'H_EFGPerc', 'H_FTR',
#        'H_TOVPerc', 'Away_Team_x', 'A_TEAM', 'DATE_y', 'MATCHUP_y', 'A_W/L',
#        'A_MIN', 'A_PTS', 'A_FGM', 'A_FGA', 'A_FGPerc', 'A_3PM', 'A_3PA',
#        'A_ThreePPerc', 'A_FTM', 'A_FTA', 'A_FTPerc', 'A_OREB', 'A_DREB',
#        'A_REB', 'A_AST', 'A_STL', 'A_BLK', 'A_TOV', 'A_PF', 'A_+/',
#        'A_EFGPerc', 'A_FTR', 'A_TOVPerc', 'Away_Team_y'],
#       dtype='object')

# %%
# Dropping duplicate columns that are not necessary 
new_df = new_df.drop(['key_0', 'key_1', 'Away_Team_x', 'DATE_y', 'MATCHUP_y', 'A_MIN', 'Away_Team_y'], axis=1)

# %%
new_df.columns
# Out:
# Index(['H_TEAM', 'DATE_x', 'MATCHUP_x', 'W/L', 'MIN', 'H_PTS', 'H_FGM',
#        'H_FGA', 'H_FGPerc', 'H_3PM', 'H_3PA', 'H_ThreePPerc', 'H_FTM', 'H_FTA',
#        'H_FTPerc', 'H_OREB', 'H_DREB', 'H_REB', 'H_AST', 'H_STL', 'H_BLK',
#        'H_TOV', 'H_PF', 'H_+/', 'H_EFGPerc', 'H_FTR', 'H_TOVPerc', 'A_TEAM',
#        'A_W/L', 'A_PTS', 'A_FGM', 'A_FGA', 'A_FGPerc', 'A_3PM', 'A_3PA',
#        'A_ThreePPerc', 'A_FTM', 'A_FTA', 'A_FTPerc', 'A_OREB', 'A_DREB',
#        'A_REB', 'A_AST', 'A_STL', 'A_BLK', 'A_TOV', 'A_PF', 'A_+/',
#        'A_EFGPerc', 'A_FTR', 'A_TOVPerc'],
#       dtype='object')

# %%
# Renaming the columns in order get ride of the % signs 
new_df.rename(columns={'DATE_x':'DATE','MATCHUP_x':'MATCHUP','W/L':'H_W/L'}, inplace=True)

# %%
new_df['H_TEAM'].value_counts()
# Out:
# GSW    372
# CLE    357
# SAS    353
# TOR    352
# HOU    351
# MIA    349
# OKC    343
# LAC    343
# BOS    342
# LAL    337
# CHI    336
# POR    333
# MEM    332
# IND    332
# ATL    328
# WAS    327
# MIL    325
# PHI    322
# BKN    322
# UTA    320
# DAL    318
# ORL    316
# CHA    315
# DET    314
# MIN    310
# DEN    310
# NYK    309
# PHX    308
# SAC    305
# NOP    267
# NOH     44
# WST      5
# USA      4
# WLD      2
# FBU      2
# FCB      2
# EST      2
# CAN      2
# RMD      2
# MLN      1
# FLA      1
# EAM      1
# HME      1
# UBB      1
# WEB      1
# CHK      1
# ALB      1
# STP      1
# Name: H_TEAM, dtype: int64

# %%
# Creating a new list to iterate through and drop non wanted game
H_Team_to_drop = ['WST', 'USA', 'RMD', 'FBU', 'EST', 'FCB', 'WLD', 'CAN', 'UBB', 'WEB', 'ALB', 'CHK', 'HME', 'MLN', 'EAM', 'FLA', 'STP']

# %%
# Dropping the unwanted columns 
df = new_df[~new_df['H_TEAM'].isin(H_Team_to_drop)]

# %%
df['H_TEAM'].value_counts()
# Out:
# GSW    372
# CLE    357
# SAS    353
# TOR    352
# HOU    351
# MIA    349
# LAC    343
# OKC    343
# BOS    342
# LAL    337
# CHI    336
# POR    333
# IND    332
# MEM    332
# ATL    328
# WAS    327
# MIL    325
# BKN    322
# PHI    322
# UTA    320
# DAL    318
# ORL    316
# CHA    315
# DET    314
# MIN    310
# DEN    310
# NYK    309
# PHX    308
# SAC    305
# NOP    267
# NOH     44
# Name: H_TEAM, dtype: int64

# %%
df['A_TEAM'].value_counts()
# Out:
# GSW    369
# SAS    350
# IND    344
# HOU    343
# CLE    342
# TOR    340
# MIA    339
# POR    338
# ATL    336
# BOS    335
# WAS    334
# OKC    333
# MEM    331
# DEN    331
# LAC    329
# MIL    328
# UTA    328
# CHI    322
# BKN    321
# DAL    319
# CHA    319
# NYK    319
# PHI    318
# DET    315
# SAC    314
# ORL    312
# MIN    312
# PHX    309
# LAL    293
# NOP    275
# NOH     46
# MAC     17
# FLA      4
# MEL      3
# SDS      3
# PER      2
# MOS      2
# SYD      2
# MTA      2
# FEN      2
# BAU      2
# GUA      2
# BJD      1
# BNE      1
# MPS      1
# RMD      1
# NZB      1
# SLA      1
# ADL      1
# Name: A_TEAM, dtype: int64

# %%
# Creating a list of away team names to drop 
A_Team_to_drop = ['MAC', 'FLA', 'SDS', 'MEL', 'MTA', 'MOS', 'BAU', 'GUA', 'SYD', 'FEN', 'PER', 'SLA', 'MPS', 'ADL', 'RMD', 'BNE', 'NZB', 'BJD']

# %%
# Dropping the unwanted away columns 
df = df[~df['A_TEAM'].isin(A_Team_to_drop)]

# %%
df
# Out:
#       H_TEAM      DATE      MATCHUP H_W/L  MIN  H_PTS  H_FGM  H_FGA  H_FGPerc  \
# 0        GSW    6/5/19  GSW vs. TOR     L  241    109     36     91      39.6
# 1        TOR    6/2/19  TOR vs. GSW     L  240    104     35     94      37.2
# 2        TOR   5/30/19  TOR vs. GSW     W  241    118     39     77      50.6
# 3        TOR   5/25/19  TOR vs. MIL     W  239    100     36     74      48.6
# 4        MIL   5/23/19  MIL vs. TOR     L  240     99     38     84      45.2
# 5        TOR   5/21/19  TOR vs. MIL     W  239    120     41     87      47.1
# 6        POR   5/20/19  POR vs. GSW     L  265    117     47     98      48.0
# 7        TOR   5/19/19  TOR vs. MIL     W  290    118     40    102      39.2
# 8        POR   5/18/19  POR vs. GSW     L  239     99     34     85      40.0
# 9        MIL   5/17/19  MIL vs. TOR     W  240    125     43     92      46.7
# 10       GSW   5/16/19  GSW vs. POR     W  242    114     42     82      51.2
# 11       MIL   5/15/19  MIL vs. TOR     W  241    108     37     93      39.8
# 12       GSW   5/14/19  GSW vs. POR     W  240    116     42     84      50.0
# 13       DEN   5/12/19  DEN vs. POR     L  240     96     33     89      37.1
# 14       TOR   5/12/19  TOR vs. PHI     W  239     92     34     89      38.2
# 15       HOU   5/10/19  HOU vs. GSW     L  240    113     42     89      47.2
# 16       PHI    5/9/19  PHI vs. TOR     W  243    112     41     89      46.1
# 17       POR    5/9/19  POR vs. DEN     W  241    119     41     89      46.1
# 18       GSW    5/8/19  GSW vs. HOU     W  240    104     39     85      45.9
# 19       MIL    5/8/19  MIL vs. BOS     W  240    116     42     94      44.7
# 20       DEN    5/7/19  DEN vs. POR     W  239    124     44     89      49.4
# 21       TOR    5/7/19  TOR vs. PHI     W  240    125     40     82      48.8
# 22       BOS    5/6/19  BOS vs. MIL     L  240    101     34     90      37.8
# 23       HOU    5/6/19  HOU vs. GSW     W  239    112     39     89      43.8
# 24       PHI    5/5/19  PHI vs. TOR     L  239     96     33     82      40.2
# 25       POR    5/5/19  POR vs. DEN     L  240    112     39     82      47.6
# 26       HOU    5/4/19  HOU vs. GSW     W  265    126     45     93      48.4
# 27       BOS    5/3/19  BOS vs. MIL     L  240    116     35     81      43.2
# 28       POR    5/3/19  POR vs. DEN     W  340    140     52    124      41.9
# 29       PHI    5/2/19  PHI vs. TOR     W  239    116     43     84      51.2
# ...      ...       ...          ...   ...  ...    ...    ...    ...       ...
# 14174    LAL  10/13/12  LAL vs. UTA     L  242     86     27     77      35.1
# 14175    CLE  10/13/12  CLE vs. WAS     L  240     95     34     85      40.0
# 14176    MIL  10/13/12  MIL vs. DET     W  241    108     38     82      46.3
# 14177    MIN  10/13/12  MIN vs. CHI     W  240     82     22     67      32.8
# 14178    TOR  10/12/12  TOR vs. DET     W  241     82     28     71      39.4
# 14179    UTA  10/12/12  UTA vs. OKC     W  239     97     34     81      42.0
# 14180    PHX  10/12/12  PHX vs. POR     W  240    104     42     82      51.2
# 14181    HOU  10/12/12  HOU vs. NOH     W  240     95     37     75      49.3
# 14182    CHI  10/12/12  CHI vs. CLE     L  241     83     30     86      34.9
# 14183    IND  10/12/12  IND vs. MIN     W  240     96     41     94      43.6
# 14184    SAS  10/12/12  SAS vs. DEN     L  241     91     33     78      42.3
# 14185    CHA  10/11/12  CHA vs. NOH     L  241     87     30     76      39.5
# 14187    ORL  10/11/12  ORL vs. PHI     L  241     95     42     93      45.2
# 14188    LAC  10/11/12  LAC vs. MIA     L  239     80     31     72      43.1
# 14189    WAS  10/11/12  WAS vs. NYK     L  241    101     33     78      42.3
# 14190    SAS  10/10/12  SAS vs. ATL     W  241    101     40     77      51.9
# 14191    SAC  10/10/12  SAC vs. PHX     W  241    102     35     86      40.7
# 14192    MIN  10/10/12  MIN vs. IND     W  240     84     30     74      40.5
# 14193    HOU  10/10/12  HOU vs. OKC     W  241    107     37     86      43.0
# 14194    DET  10/10/12  DET vs. TOR     W  240    101     41     81      50.6
# 14195    LAL  10/10/12  LAL vs. POR     L  242     75     27     71      38.0
# 14196    CLE   10/9/12  CLE vs. MIL     L  239     80     30     78      38.5
# 14197    NOH   10/9/12  NOH vs. CHA     W  239     97     38     87      43.7
# 14198    CHI   10/9/12  CHI vs. MEM     W  240     92     30     84      35.7
# 14200    GSW   10/8/12  GSW vs. UTA     W  240     83     37     79      46.8
# 14203    LAL   10/7/12  LAL vs. GSW     L  242     83     28     71      39.4
# 14204    NOH   10/7/12  NOH vs. ORL     W  240     85     29     78      37.2
# 14205    CHA   10/7/12  CHA vs. WAS     W  239    100     32     71      45.1
# 14207    ATL   10/7/12  ATL vs. MIA     W  241     92     33     80      41.3
# 14208    LAC   10/6/12  LAC vs. DEN     L  239    104     43     84      51.2
#
#        H_3PM    ...      A_REB  A_AST  A_STL  A_BLK  A_TOV  A_PF  A_+/  \
# 0         12    ...         40     30      9     10     14    22  14.0
# 1         11    ...         42     34      7      5     15    26   5.0
# 2         13    ...         38     29      6      2     16    27  -9.0
# 3         12    ...         42     19      7      7     11    22  -6.0
# 4         10    ...         45     19      6      4      6    16   6.0
# 5         14    ...         40     30      8      7     12    22 -18.0
# 6         16    ...         56     30     10      5     15    17   2.0
# 7         17    ...         63     22     14      5     20    30  -6.0
# 8         11    ...         49     27      9      5     13    24  11.0
# 9         13    ...         40     19      3      6     13    30 -22.0
# 10         9    ...         37     23      8      1     13    22  -3.0
# 11        11    ...         46     17      9      4     12    21  -8.0
# 12        17    ...         47     21      5      5     21    16 -22.0
# 13         2    ...         55     16      5      7      4    31   4.0
# 14         7    ...         41     16      4      7     15    21  -2.0
# 15        17    ...         35     25      9      7     17    19   5.0
# 16        10    ...         34     25      9      4     12    24 -11.0
# 17        15    ...         44     22      7      3      6    23 -11.0
# 18        13    ...         39     19     10      3     15    20  -5.0
# 19        15    ...         48     19      9      1     14    18 -25.0
# 20         8    ...         43     19      6      5      6    23 -26.0
# 21        16    ...         37     19      6      5     19    26 -36.0
# 22         9    ...         56     25      4      5      7    25  12.0
# 23        17    ...         43     24      6      2     11    21  -4.0
# 24        12    ...         43     19      6      3     13    24   5.0
# 25        12    ...         45     21      7      4      8    22   4.0
# 26        18    ...         35     27      6      6      8    22  -5.0
# 27        16    ...         44     23      8      7     15    26   7.0
# 28        12    ...         66     28     11      8     20    27  -3.0
# 29        10    ...         35     15      7      4      9    17 -21.0
# ...      ...    ...        ...    ...    ...    ...    ...   ...   ...
# 14174      4    ...         49     21     11      9     13    25  13.0
# 14175      6    ...         43     26     10      4     16    26   4.0
# 14176      5    ...         42     23      9      4     20    31 -17.0
# 14177      4    ...         43     10     10      7     23    39  -7.0
# 14178      5    ...         45     16     11      7     23    28  -7.0
# 14179      3    ...         47     16     10      6     21    27 -16.0
# 14180     10    ...         47     19      9      4     17    18 -11.0
# 14181      8    ...         44     17      8      5     18    19 -20.0
# 14182      1    ...         34     17     10      3     24    28   3.0
# 14183      5    ...         38     19      9     13     18    18  -5.0
# 14184      6    ...         48     16     12      3     24    27   6.0
# 14185      5    ...         45     19      4      5     21    26   3.0
# 14187      3    ...         43     17      5      4     15    14   7.0
# 14188      7    ...         34     19     12      6     12    28  14.0
# 14189     11    ...         32     26      8      0     15    25   7.0
# 14190      8    ...         43     23     11      3     13    22  -2.0
# 14191      6    ...         47     24      6      6     17    21  -6.0
# 14192      4    ...         39     14      7      4     24    27 -14.0
# 14193      6    ...         38     22     11      5     15    27  -2.0
# 14194      0    ...         32     20     11      5     15    26  -2.0
# 14195      2    ...         48     23      8      5     15    21  18.0
# 14196      6    ...         42     22     11      8     12    16  17.0
# 14197      7    ...         42     18      5      9     19    19 -15.0
# 14198      2    ...         51     21     12      3     22    28  -4.0
# 14200      3    ...         43     20      6      6     18    17  -3.0
# 14203      5    ...         40     21      5      5     14    22  27.0
# 14204      6    ...         46     20      8      2     20    29  -5.0
# 14205      5    ...         49     14     11      4     20    31 -12.0
# 14207      8    ...         41     20     10      2     22    23 -13.0
# 14208      4    ...         34     25     13      3     26    24   2.0
#
#        A_EFGPerc     A_FTR  A_TOVPerc
# 0       0.628049  0.256098  13.302927
# 1       0.542683  0.280488  14.002987
# 2       0.512821  0.397436  14.864363
# 3       0.480000  0.413333  11.039743
# 4       0.476190  0.369048   5.789271
# 5       0.531250  0.325000  11.600928
# 6       0.525253  0.191919  12.258908
# 7       0.441176  0.323529  14.649868
# 8       0.535714  0.273810  12.135922
# 9       0.482759  0.287356  11.711712
# 10      0.546512  0.209302  12.158623
# 11      0.451087  0.217391  10.638298
# 12      0.403614  0.373494  17.851071
# 13      0.430108  0.258065   3.718855
# 14      0.500000  0.461538  16.094421
# 15      0.588235  0.270588  15.162326
# 16      0.487654  0.358025  11.346445
# 17      0.453488  0.372093   5.656109
# 18      0.493671  0.303797  14.345830
# 19      0.349462  0.365591  11.479173
# 20      0.418367  0.306122   5.119454
# 21      0.455696  0.253165  17.790262
# 22      0.480000  0.250000   5.932203
# 23      0.511111  0.255556   9.899208
# 24      0.526316  0.342105  12.943051
# 25      0.494565  0.304348   7.122507
# 26      0.515789  0.305263   6.910850
# 27      0.596386  0.433735  13.176388
# 28      0.516807  0.168067  13.531800
# 29      0.463855  0.277108   8.813161
# ...          ...       ...        ...
# 14174   0.463415  0.390244  11.917858
# 14175   0.506667  0.453333  15.100038
# 14176   0.436782  0.264368  17.076503
# 14177   0.389706  0.514706  21.616541
# 14178   0.373333  0.346667  21.016082
# 14179   0.391026  0.358974  18.864535
# 14180   0.431818  0.227273  14.938489
# 14181   0.385542  0.192771  16.660496
# 14182   0.479452  0.328767  22.313128
# 14183   0.520548  0.273973  18.036072
# 14184   0.475610  0.390244  19.986676
# 14185   0.486301  0.328767  20.084162
# 14187   0.500000  0.235294  13.786765
# 14188   0.474026  0.337662  11.947431
# 14189   0.597222  0.388889  15.102698
# 14190   0.425532  0.244681  11.099727
# 14191   0.454023  0.298851  14.726265
# 14192   0.386364  0.378788  23.762376
# 14193   0.516667  0.155556  13.494063
# 14194   0.547297  0.378378  14.804580
# 14195   0.488235  0.141176  14.247720
# 14196   0.476190  0.226190  11.498658
# 14197   0.493333  0.200000  18.886680
# 14198   0.433735  0.325301  18.822724
# 14200   0.406250  0.250000  16.853933
# 14203   0.623288  0.438356  13.850416
# 14204   0.402778  0.388889  19.171779
# 14205   0.363636  0.212121  15.595758
# 14207   0.485915  0.225352  21.991204
# 14208   0.584416  0.337662  22.719329
#
# [9844 rows x 51 columns]

# %%
df.columns
# Out:
# Index(['H_TEAM', 'DATE', 'MATCHUP', 'H_W/L', 'MIN', 'H_PTS', 'H_FGM', 'H_FGA',
#        'H_FGPerc', 'H_3PM', 'H_3PA', 'H_ThreePPerc', 'H_FTM', 'H_FTA',
#        'H_FTPerc', 'H_OREB', 'H_DREB', 'H_REB', 'H_AST', 'H_STL', 'H_BLK',
#        'H_TOV', 'H_PF', 'H_+/', 'H_EFGPerc', 'H_FTR', 'H_TOVPerc', 'A_TEAM',
#        'A_W/L', 'A_PTS', 'A_FGM', 'A_FGA', 'A_FGPerc', 'A_3PM', 'A_3PA',
#        'A_ThreePPerc', 'A_FTM', 'A_FTA', 'A_FTPerc', 'A_OREB', 'A_DREB',
#        'A_REB', 'A_AST', 'A_STL', 'A_BLK', 'A_TOV', 'A_PF', 'A_+/',
#        'A_EFGPerc', 'A_FTR', 'A_TOVPerc'],
#       dtype='object')

# %%
#df['Target'] = df['H_PTS'] - df['A_PTS']

# %%
# Creating the Target column from the Result column
df['Target_L'] = df['H_W/L'].astype(str).str[0]

# %%
# Creating a function to bin the target variable
def target_binning(Target_L):
    if str(Target_L) == 'L':  # Will return 0 if a team loses the game
        return(0)
    else:                   # Will return 1 if a team wins the game
        return(1)

# %%
# Applying the function in order to bin the target variable 
df['Target'] = df['Target_L'].apply(target_binning)

# %%
df = df.drop(['Target_L'], axis=1)

# %%
df.columns
# Out:
# Index(['H_TEAM', 'DATE', 'MATCHUP', 'H_W/L', 'MIN', 'H_PTS', 'H_FGM', 'H_FGA',
#        'H_FGPerc', 'H_3PM', 'H_3PA', 'H_ThreePPerc', 'H_FTM', 'H_FTA',
#        'H_FTPerc', 'H_OREB', 'H_DREB', 'H_REB', 'H_AST', 'H_STL', 'H_BLK',
#        'H_TOV', 'H_PF', 'H_+/', 'H_EFGPerc', 'H_FTR', 'H_TOVPerc', 'A_TEAM',
#        'A_W/L', 'A_PTS', 'A_FGM', 'A_FGA', 'A_FGPerc', 'A_3PM', 'A_3PA',
#        'A_ThreePPerc', 'A_FTM', 'A_FTA', 'A_FTPerc', 'A_OREB', 'A_DREB',
#        'A_REB', 'A_AST', 'A_STL', 'A_BLK', 'A_TOV', 'A_PF', 'A_+/',
#        'A_EFGPerc', 'A_FTR', 'A_TOVPerc', 'Target'],
#       dtype='object')

# %%
# Dropping duplicate columns that are not necessary 
df = df.drop(['H_W/L', 'H_PTS', 'H_+/', 'A_W/L', 'A_PTS', 'A_+/'], axis=1)

# %%
df.columns
# Out:
# Index(['H_TEAM', 'DATE', 'MATCHUP', 'MIN', 'H_FGM', 'H_FGA', 'H_FGPerc',
#        'H_3PM', 'H_3PA', 'H_ThreePPerc', 'H_FTM', 'H_FTA', 'H_FTPerc',
#        'H_OREB', 'H_DREB', 'H_REB', 'H_AST', 'H_STL', 'H_BLK', 'H_TOV', 'H_PF',
#        'H_EFGPerc', 'H_FTR', 'H_TOVPerc', 'A_TEAM', 'A_FGM', 'A_FGA',
#        'A_FGPerc', 'A_3PM', 'A_3PA', 'A_ThreePPerc', 'A_FTM', 'A_FTA',
#        'A_FTPerc', 'A_OREB', 'A_DREB', 'A_REB', 'A_AST', 'A_STL', 'A_BLK',
#        'A_TOV', 'A_PF', 'A_EFGPerc', 'A_FTR', 'A_TOVPerc', 'Target'],
#       dtype='object')

# %%
columns = ['DATE', 'MATCHUP', 'MIN', 'H_TEAM', 'A_TEAM', 'H_FGM', 'H_FGA',
       'H_FGPerc', 'H_3PM', 'H_3PA', 'H_ThreePPerc', 'H_FTM', 'H_FTA',
       'H_FTPerc', 'H_OREB', 'H_DREB', 'H_REB', 'H_AST', 'H_STL', 'H_BLK',
       'H_TOV', 'H_PF', 'H_EFGPerc', 'H_FTR', 'H_TOVPerc', 
     'A_FGM', 'A_FGA', 'A_FGPerc', 'A_3PM', 'A_3PA',
       'A_ThreePPerc', 'A_FTM', 'A_FTA', 'A_FTPerc', 'A_OREB', 'A_DREB',
       'A_REB', 'A_AST', 'A_STL', 'A_BLK', 'A_TOV', 'A_PF',
       'A_EFGPerc', 'A_FTR', 'A_TOVPerc', 'Target' ]

# %%
df.head()
# Out:
#   H_TEAM     DATE      MATCHUP  MIN  H_FGM  H_FGA  H_FGPerc  H_3PM  H_3PA  \
# 0    GSW   6/5/19  GSW vs. TOR  241     36     91      39.6     12     36
# 1    TOR   6/2/19  TOR vs. GSW  240     35     94      37.2     11     38
# 2    TOR  5/30/19  TOR vs. GSW  241     39     77      50.6     13     33
# 3    TOR  5/25/19  TOR vs. MIL  239     36     74      48.6     12     27
# 4    MIL  5/23/19  MIL vs. TOR  240     38     84      45.2     10     31
#
#    H_ThreePPerc   ...    A_REB  A_AST  A_STL  A_BLK  A_TOV  A_PF  A_EFGPerc  \
# 0          33.3   ...       40     30      9     10     14    22   0.628049
# 1          28.9   ...       42     34      7      5     15    26   0.542683
# 2          39.4   ...       38     29      6      2     16    27   0.512821
# 3          44.4   ...       42     19      7      7     11    22   0.480000
# 4          32.3   ...       45     19      6      4      6    16   0.476190
#
#       A_FTR  A_TOVPerc  Target
# 0  0.256098  13.302927       0
# 1  0.280488  14.002987       0
# 2  0.397436  14.864363       1
# 3  0.413333  11.039743       1
# 4  0.369048   5.789271       0
#
# [5 rows x 46 columns]

# %%
df = pd.DataFrame(df, columns = ['DATE', 'MATCHUP', 'MIN', 'H_TEAM', 'A_TEAM', 'H_FGM', 'H_FGA',
       'H_FGPerc', 'H_3PM', 'H_3PA', 'H_ThreePPerc', 'H_FTM', 'H_FTA',
       'H_FTPerc', 'H_OREB', 'H_DREB', 'H_REB', 'H_AST', 'H_STL', 'H_BLK',
       'H_TOV', 'H_PF', 'H_EFGPerc', 'H_FTR', 'H_TOVPerc', 
     'A_FGM', 'A_FGA', 'A_FGPerc', 'A_3PM', 'A_3PA',
       'A_ThreePPerc', 'A_FTM', 'A_FTA', 'A_FTPerc', 'A_OREB', 'A_DREB',
       'A_REB', 'A_AST', 'A_STL', 'A_BLK', 'A_TOV', 'A_PF',
       'A_EFGPerc', 'A_FTR', 'A_TOVPerc', 'Target' ])

# %%
df.columns
# Out:
# Index(['DATE', 'MATCHUP', 'MIN', 'H_TEAM', 'A_TEAM', 'H_FGM', 'H_FGA',
#        'H_FGPerc', 'H_3PM', 'H_3PA', 'H_ThreePPerc', 'H_FTM', 'H_FTA',
#        'H_FTPerc', 'H_OREB', 'H_DREB', 'H_REB', 'H_AST', 'H_STL', 'H_BLK',
#        'H_TOV', 'H_PF', 'H_EFGPerc', 'H_FTR', 'H_TOVPerc', 'A_FGM', 'A_FGA',
#        'A_FGPerc', 'A_3PM', 'A_3PA', 'A_ThreePPerc', 'A_FTM', 'A_FTA',
#        'A_FTPerc', 'A_OREB', 'A_DREB', 'A_REB', 'A_AST', 'A_STL', 'A_BLK',
#        'A_TOV', 'A_PF', 'A_EFGPerc', 'A_FTR', 'A_TOVPerc', 'Target'],
#       dtype='object')

# %%
df['H_FTPerc'] = df['H_FTPerc'] / 100
df['A_FTPerc'] = df['A_FTPerc'] / 100

# %%
df.head()
# Out:
#       DATE      MATCHUP  MIN H_TEAM A_TEAM  H_FGM  H_FGA  H_FGPerc  H_3PM  \
# 0   6/5/19  GSW vs. TOR  241    GSW    TOR     36     91      39.6     12
# 1   6/2/19  TOR vs. GSW  240    TOR    GSW     35     94      37.2     11
# 2  5/30/19  TOR vs. GSW  241    TOR    GSW     39     77      50.6     13
# 3  5/25/19  TOR vs. MIL  239    TOR    MIL     36     74      48.6     12
# 4  5/23/19  MIL vs. TOR  240    MIL    TOR     38     84      45.2     10
#
#    H_3PA   ...    A_REB  A_AST  A_STL  A_BLK  A_TOV  A_PF  A_EFGPerc  \
# 0     36   ...       40     30      9     10     14    22   0.628049
# 1     38   ...       42     34      7      5     15    26   0.542683
# 2     33   ...       38     29      6      2     16    27   0.512821
# 3     27   ...       42     19      7      7     11    22   0.480000
# 4     31   ...       45     19      6      4      6    16   0.476190
#
#       A_FTR  A_TOVPerc  Target
# 0  0.256098  13.302927       0
# 1  0.280488  14.002987       0
# 2  0.397436  14.864363       1
# 3  0.413333  11.039743       1
# 4  0.369048   5.789271       0
#
# [5 rows x 46 columns]

# %%
df.head()
# Out:
#       DATE      MATCHUP  MIN H_TEAM A_TEAM  H_FGM  H_FGA  H_FGPerc  H_3PM  \
# 0   6/5/19  GSW vs. TOR  241    GSW    TOR     36     91      39.6     12
# 1   6/2/19  TOR vs. GSW  240    TOR    GSW     35     94      37.2     11
# 2  5/30/19  TOR vs. GSW  241    TOR    GSW     39     77      50.6     13
# 3  5/25/19  TOR vs. MIL  239    TOR    MIL     36     74      48.6     12
# 4  5/23/19  MIL vs. TOR  240    MIL    TOR     38     84      45.2     10
#
#    H_3PA   ...    A_REB  A_AST  A_STL  A_BLK  A_TOV  A_PF  A_EFGPerc  \
# 0     36   ...       40     30      9     10     14    22   0.628049
# 1     38   ...       42     34      7      5     15    26   0.542683
# 2     33   ...       38     29      6      2     16    27   0.512821
# 3     27   ...       42     19      7      7     11    22   0.480000
# 4     31   ...       45     19      6      4      6    16   0.476190
#
#       A_FTR  A_TOVPerc  Target
# 0  0.256098  13.302927       0
# 1  0.280488  14.002987       0
# 2  0.397436  14.864363       1
# 3  0.413333  11.039743       1
# 4  0.369048   5.789271       0
#
# [5 rows x 46 columns]

# %%
# export working dataframe for Regression to csv
df.to_csv('csv_files/FinishedDataset_Classification.csv')
