# %%
# import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# read the csv file 
df = pd.read_csv('../csv_files/Capstone_p1_iqr.csv', index_col=0)
df.head()
# Out:
#      PTS   FGM   FGA  FGPerc   3PM   3PA  3PPerc   FTM   FTA  FTPerc  OREB  \
# 0  109.0  36.0  91.0    39.6  12.0  36.0    33.3  25.0  30.0    83.3  13.0
# 1  123.0  43.0  82.0    52.4  17.0  38.0    44.7  20.0  21.0    95.2   5.0
# 2  109.0  38.0  82.0    46.3  13.0  34.0    38.2  20.0  23.0    87.0   6.0
# 3  104.0  35.0  94.0    37.2  11.0  38.0    28.9  23.0  26.0    88.5  15.0
# 4  109.0  34.0  78.0    43.6  12.0  31.0    38.7  29.0  31.0    93.5   9.0
#
#    DREB   REB   AST  STL   BLK   TOV    PF   EFGPerc       FTR
# 0  28.0  41.0  25.0  8.0   3.0  14.0  21.0  0.461538  0.329670
# 1  35.0  40.0  30.0  9.0  10.0  14.0  22.0  0.628049  0.256098
# 2  36.0  42.0  34.0  7.0   5.0  15.0  26.0  0.542683  0.280488
# 3  34.0  49.0  17.0  8.0   2.0  15.0  22.0  0.430851  0.276596
# 4  29.0  38.0  29.0  6.0   2.0  16.0  27.0  0.512821  0.397436

# %%
# Getting a list of column names 
df.columns
# Out:
# Index(['PTS', 'FGM', 'FGA', 'FGPerc', '3PM', '3PA', '3PPerc', 'FTM', 'FTA',
#        'FTPerc', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'EFGPerc', 'FTR'],
#       dtype='object')

# %%
# import the preprocessing package from sklearn
from sklearn import preprocessing

# define column names
cols = ['PTS','FGM','FGA','FGPerc','3PM','3PA','3PPerc','FTM','FTA','FTPerc','OREB','DREB','REB','AST','STL','BLK','TOV','PF','EFGPerc','FTR']

# scale all columns to have a range of 0-1
x = df.values
scaler = preprocessing.MinMaxScaler()
x_scaled = scaler.fit_transform(x)
df_scaled = pd.DataFrame(x_scaled,columns=cols)
df_scaled.head()
# Out:
#         PTS       FGM    FGA    FGPerc       3PM    3PA    3PPerc      FTM  \
# 0  0.583333  0.410714  0.675  0.307432  0.648649  0.775  0.464695  0.75000
# 1  0.777778  0.660714  0.450  0.739865  0.918919  0.825  0.682252  0.59375
# 2  0.583333  0.482143  0.450  0.533784  0.702703  0.725  0.558206  0.59375
# 3  0.513889  0.375000  0.750  0.226351  0.594595  0.825  0.380725  0.68750
# 4  0.583333  0.339286  0.350  0.442568  0.648649  0.650  0.567748  0.87500
#
#      FTA    FTPerc   OREB     DREB       REB       AST     STL       BLK  \
# 0  0.675  0.678537  0.625  0.34375  0.430556  0.589286  0.5000  0.285714
# 1  0.450  0.907603  0.225  0.56250  0.402778  0.767857  0.5625  0.952381
# 2  0.500  0.749759  0.275  0.59375  0.458333  0.910714  0.4375  0.476190
# 3  0.575  0.778633  0.725  0.53125  0.652778  0.303571  0.5000  0.190476
# 4  0.700  0.874880  0.425  0.37500  0.347222  0.732143  0.3750  0.190476
#
#      TOV        PF   EFGPerc       FTR
# ...

# %%
# verify that the min and max values for each column are 0 and 1 respectively 
df_scaled.describe()
# Out:
#                 PTS           FGM           FGA        FGPerc           3PM  \
# count  22695.000000  22695.000000  22695.000000  22695.000000  22695.000000
# mean       0.500890      0.492622      0.512406      0.503423      0.479577
# std        0.175804      0.184917      0.184776      0.186540      0.196218
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.375000      0.375000      0.375000      0.375000      0.324324
# 50%        0.500000      0.482143      0.500000      0.500000      0.486486
# 75%        0.625000      0.625000      0.625000      0.625000      0.594595
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                 3PA        3PPerc           FTM           FTA        FTPerc  \
# count  22695.000000  22695.000000  22695.000000  22695.000000  22695.000000
# mean       0.500543      0.502595      0.517149      0.504238      0.536472
# ...

# %%
# export new dataframe to csv
df_scaled.to_csv('../csv_files/Capstone_p1_minmax.csv')
