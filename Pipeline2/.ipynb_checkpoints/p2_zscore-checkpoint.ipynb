# %% [markdown]
# ## Pipeline 2 - Z-Score

# %%
# import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
# read the excel file
dfx = pd.read_csv('../csv_files/Capstone_p2_3stdev.csv',index_col=0)
dfx.head(10)
# Out:
#    H_FTPct  H_EFGPct  H_ThreePARt     H_FTR  H_REBPct  H_BLKPct  \
# 0    0.833  0.461538     0.395604  0.574169  0.506173  0.191273
# 1    0.885  0.430851     0.404255  0.525924  0.538462  0.156174
# 2    0.844  0.590909     0.428571  0.644658  0.486486  0.277350
# 3    0.727  0.567568     0.364865  0.545250  0.475000  0.230940
# 4    0.722  0.511905     0.369048  0.462910  0.540816  0.154303
# 5    0.889  0.551724     0.471264  0.557086  0.523810  0.250000
# 6    0.700  0.561224     0.418367  0.319438  0.404255  0.246183
# 7    0.808  0.475490     0.441176  0.504878  0.466102  0.313112
# 8    0.606  0.464706     0.411765  0.623085  0.455556  0.188982
# 9    0.743  0.538043     0.445652  0.616794  0.569892  0.214423
#
#    H_AST_TOV_Ratio  A_FTPct  A_EFGPct  A_ThreePARt     A_FTR  A_REBPct  \
# 0         1.101460    0.952  0.628049     0.463415  0.711380  0.493827
# 1         1.021080    0.870  0.542683     0.414634  0.727744  0.461538
# ...

# %%
# define column names
names = dfx.columns

# create scaler variable 
scaler = preprocessing.StandardScaler()

# fit and scale data 
dfxstandard = scaler.fit_transform(dfx)
dfxstandard = pd.DataFrame(dfxstandard, columns=names)

# %%
# Looking to see if the data was properly scaled
dfxstandard.describe()
# Out:
#             H_FTPct      H_EFGPct   H_ThreePARt         H_FTR      H_REBPct  \
# count  9.844000e+03  9.844000e+03  9.844000e+03  9.844000e+03  9.844000e+03
# mean  -5.976528e-16  5.774423e-17  2.887211e-16  3.089316e-16  7.373216e-16
# std    1.000051e+00  1.000051e+00  1.000051e+00  1.000051e+00  1.000051e+00
# min   -3.031014e+00 -3.001020e+00 -3.000228e+00 -3.002531e+00 -3.006381e+00
# 25%   -6.367731e-01 -6.929506e-01 -7.172756e-01 -6.680956e-01 -6.673335e-01
# 50%    6.338830e-02 -3.049260e-02 -4.666452e-02 -4.983661e-03 -1.174683e-02
# 75%    7.142425e-01  6.757681e-01  6.577790e-01  6.452800e-01  6.637951e-01
# max    2.361101e+00  3.007247e+00  3.025786e+00  3.017857e+00  3.010842e+00
#
#            H_BLKPct  H_AST_TOV_Ratio       A_FTPct      A_EFGPct  \
# count  9.844000e+03     9.844000e+03  9.844000e+03  9.844000e+03
# mean  -1.270373e-16    -1.772748e-15  2.280897e-16  8.892611e-16
# std    1.000051e+00     1.000051e+00  1.000051e+00  1.000051e+00
# ...

# %%
# Creating a box plot to detect outliers
plt.boxplot(dfx.H_FTPct)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fba4c2dc1d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fba4c2dc898>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fba4c2dc080>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fba4c2dcf28>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fba4c2e32b0>],
#  'means': []}

# %%
# reading in the target variable
y = pd.read_csv('../csv_files/TargetVariable_p1_Classification.csv',index_col=0)

# %%
# Joining the variables back with the target 
df = pd.concat([dfx, y],axis=1,join='inner')
df.head()
# Out:
#    H_FTPct  H_EFGPct  H_ThreePARt     H_FTR  H_REBPct  H_BLKPct  \
# 0    0.833  0.461538     0.395604  0.574169  0.506173  0.191273
# 1    0.885  0.430851     0.404255  0.525924  0.538462  0.156174
# 2    0.844  0.590909     0.428571  0.644658  0.486486  0.277350
# 3    0.727  0.567568     0.364865  0.545250  0.475000  0.230940
# 4    0.722  0.511905     0.369048  0.462910  0.540816  0.154303
#
#    H_AST_TOV_Ratio  A_FTPct  A_EFGPct  A_ThreePARt     A_FTR  A_REBPct  \
# 0         1.101460    0.952  0.628049     0.463415  0.711380  0.493827
# 1         1.021080    0.870  0.542683     0.414634  0.727744  0.461538
# 2         1.164993    0.935  0.512821     0.397436  0.793993  0.513514
# 3         1.122462    0.710  0.480000     0.453333  0.801817  0.525000
# 4         1.154153    0.806  0.476190     0.511905  0.779418  0.459184
#
#    A_BLKPct  A_AST_TOV_Ratio  Target
# 0  0.109890         1.135444       0
# 1  0.053191         1.146123       0
# 2  0.025974         1.104196       1
# ...

# %%
# Saving to a csv
df.to_csv('../csv_files/Capstone_p2_final_Classification.csv')
