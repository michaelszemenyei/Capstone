# %%
# import packages 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# read min/max csv file
df = pd.read_csv('../csv_files/Capstone_p1_minmax.csv', index_col=0)
df.head()
# Out:
#         PTS       FGM    FGA    FGPerc       3PM    3PA    3PPerc      FTM  \
# 0  0.583333  0.410714  0.675  0.307432  0.648649  0.775  0.464695  0.75000
# 1  0.777778  0.660714  0.450  0.739865  0.918919  0.825  0.682252  0.59375
# 2  0.583333  0.482143  0.450  0.533784  0.702703  0.725  0.558206  0.59375
# 3  0.513889  0.375000  0.750  0.226351  0.594595  0.825  0.380725  0.68750
# 4  0.583333  0.339286  0.350  0.442568  0.648649  0.650  0.567748  0.87500
#
#      FTA    FTPerc   OREB     DREB       REB       AST     STL       BLK  \
# 0  0.675  0.678537  0.625  0.34375  0.430556  0.589286  0.5000  0.285714
# 1  0.450  0.907603  0.225  0.56250  0.402778  0.767857  0.5625  0.952381
# 2  0.500  0.749759  0.275  0.59375  0.458333  0.910714  0.4375  0.476190
# 3  0.575  0.778633  0.725  0.53125  0.652778  0.303571  0.5000  0.190476
# 4  0.700  0.874880  0.425  0.37500  0.347222  0.732143  0.3750  0.190476
#
#      TOV        PF   EFGPerc       FTR
# ...

# %%
# exmaine skew for variables
df.skew()
# Out:
# PTS        0.131033
# FGM        0.121888
# FGA        0.148671
# FGPerc     0.082236
# 3PM        0.402517
# 3PA        0.318614
# 3PPerc     0.078369
# FTM        0.308185
# FTA        0.317539
# FTPerc    -0.260780
# OREB       0.349582
# DREB       0.125599
# REB        0.130640
# AST        0.217696
# STL        0.349846
# BLK        0.386131
# TOV        0.211133
# PF         0.208875
# EFGPerc    0.127757
# FTR        0.437650
# dtype: float64

# %% [markdown]
# ## Do not need to adjust for skewness since all variables are within the desired range of 0.5 to -0.5

# %%
df['PTS'].hist()

# %%
df['3PM'].hist()

# %%
# Bringing in Target Variable to join datasets
dfy = pd.read_csv('../csv_files/TargetVariable_p1.csv', index_col=0)
dfy.head()
# Out:
#    Target
# 0       0
# 1       1
# 2       1
# 3       0
# 4       0

# %%
df_combined = pd.concat([df, dfy], axis=1)

# %%
df_combined
# Out:
#             PTS       FGM    FGA    FGPerc       3PM    3PA    3PPerc  \
# 0      0.583333  0.410714  0.675  0.307432  0.648649  0.775  0.464695
# 1      0.777778  0.660714  0.450  0.739865  0.918919  0.825  0.682252
# 2      0.583333  0.482143  0.450  0.533784  0.702703  0.725  0.558206
# 3      0.513889  0.375000  0.750  0.226351  0.594595  0.825  0.380725
# 4      0.583333  0.339286  0.350  0.442568  0.648649  0.650  0.567748
# 5      0.708333  0.517857  0.325  0.679054  0.702703  0.700  0.581107
# 6      0.375000  0.196429  0.275  0.320946  0.648649  0.725  0.502863
# 7      0.458333  0.410714  0.250  0.611486  0.648649  0.550  0.676527
# 8      0.444444  0.482143  0.500  0.496622  0.540541  0.650  0.445611
# 9      0.527778  0.232143  0.500  0.216216  0.972973  0.950  0.628817
# 10     0.486111  0.446429  0.400  0.533784  0.594595  0.750  0.428435
# 11     0.736111  0.589286  0.575  0.560811  0.756757  0.900  0.479962
# ...

# %%
# export new dataframe to csv
df_combined.to_csv('../csv_files/Capstone_p1_skewed.csv')
